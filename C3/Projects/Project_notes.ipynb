# %% [markdown]
# ### P1 - Financial Data Extraction Tool
#
# In this tool you can copy paste any article and it will extract financial data from that article
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
