# %% [markdown]
# ### Vector Database - From Embeddings to Applications
#
# LLM doesnt have any idea about recent knoweledge. TO tackle this problem we can use Retrieval Augmented Generation.
#
# KEY component of RAG is Vector Database.
#
# All information is stored in vector database. Whenever any query is sent to vector database it retrieves the similar vector . This retrieved text is then given to LLM as context and then it generates the output.
#
# ![image.png](attachment:image.png)
