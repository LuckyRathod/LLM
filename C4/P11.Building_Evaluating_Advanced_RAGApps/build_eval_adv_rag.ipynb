# %% [markdown]
# ### Buidling and Evluating Advanced RAG Applcations
#
# You should use highly effective retrieval techniques which gives the context to LLM .
#
# 2 Advance Retrieval Methods - Which helps to give better context to LLM :
# - Sentence Window Retrieval
#     - It gives better context to LLM by not only retrieving sentence but also window of sentences that occure before and after the document
# - Auto merger Retrieval
#     - It organizes the document into Tree like structure
#
# To Evaluate RAG Based LLM Apps . RAG TRIAD is used.
#
# In this course we will build QA system with Sentence window retrieval and Auto Merger retrieval . We will the evaluate and compare there performance on RAG TRIAD - Context Retrieval , Groundedness , Answer Relevance

# %% [markdown]
# ### Basic RAG Pipeline
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### RAG TRIAD Metrics (Context Relevance,Groudedness,Answer Relevance)
#
# Here we will learn - How to evluate RAG Systems .
