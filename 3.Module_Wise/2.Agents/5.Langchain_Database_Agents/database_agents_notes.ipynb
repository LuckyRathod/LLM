# %% [markdown]
# ### Database Agents using Langchain

# %% [markdown]
# We will learn following things :
#
# - Implement RAG with Tabular Data
# - Function Calling
# - Integrate Azure Open AI Assistance API
#
# ### Agents Basics
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Interacting with SQL using RAG
#
# ![image.png](attachment:image.png)
