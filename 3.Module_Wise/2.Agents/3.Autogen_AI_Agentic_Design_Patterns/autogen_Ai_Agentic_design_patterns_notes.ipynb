# %% [markdown]
# ## AI Agentic Design Patterns - AutoGen
#
# AUTOGEN
#
# - Its a Multiagent conversational framework which helps you to create agents with different roles,personas etc using different AI Agentic Design Patterns
#
# In this session , You will learn best practices for creating Multi Agent System
#
# ![image.png](attachment:image.png)
