# %% [markdown]
# ### Desgin Patterns for Agentic Workflows
#
# - Planning
# - Tools Use
# - Reflection (Iteratively Improve Result)
# - Multi Agent Communication
# - Memory
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 2. Agent Search Tools
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
