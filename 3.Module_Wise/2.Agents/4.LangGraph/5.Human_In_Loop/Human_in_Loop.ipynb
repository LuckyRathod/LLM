# %% [markdown]
# # Lesson 5: Human in the Loop

# %% [markdown]
# Note: This notebook is running in a later version of langgraph that it was filmed with. The later version has a couple of key additions:
# - Additional state information is stored to memory and displayed when using `get_state()` or `get_state_history()`.
# - State is additionally stored every state transition while previously it was stored at an interrupt or at the end.
# These change the command output slightly, but are a useful addtion to the information available.

# %%
from dotenv import load_dotenv

_ = load_dotenv()

# %%
from langgraph.graph import StateGraph, END
from typing import TypedDict, Annotated
import operator
from langchain_core.messages import AnyMessage, SystemMessage, HumanMessage, ToolMessage
from langchain_openai import ChatOpenAI
from langchain_community.tools.tavily_search import TavilySearchResults
from langgraph.checkpoint.sqlite import SqliteSaver

memory = SqliteSaver.from_conn_string(":memory:")

# %%
from uuid import uuid4
from langchain_core.messages import AnyMessage, SystemMessage, HumanMessage, AIMessage

"""
In previous examples we've annotated the `messages` state key
with the default `operator.add` or `+` reducer, which always
appends new messages to the end of the existing messages array.

Now, to support replacing existing messages, we annotate the
`messages` key with a customer reducer function, which replaces
messages with the same `id`, and appends them otherwise.
"""

## Since human is in the loop , We might have to replace the older messages 
def reduce_messages(left: list[AnyMessage], right: list[AnyMessage]) -> list[AnyMessage]:
    # assign ids to messages that don't have them
    for message in right:
        if not message.id:
            message.id = str(uuid4())
    # merge the new messages with the existing messages
    merged = left.copy()
    for message in right:
        for i, existing in enumerate(merged):
            # replace any existing messages with the same id
            if existing.id == message.id:
                merged[i] = message
                break
        else:
            # append any new messages to the end
            merged.append(message)
    return merged

class AgentState(TypedDict):
    messages: Annotated[list[AnyMessage], reduce_messages]

# %%
tool = TavilySearchResults(max_results=2)

# %% [markdown]
# ## Manual human approval

# %%
class Agent:
    def __init__(self, model, tools, system="", checkpointer=None):
        self.system = system
        graph = StateGraph(AgentState)
        graph.add_node("llm", self.call_openai)
        graph.add_node("action", self.take_action)
        graph.add_conditional_edges("llm", self.exists_action, {True: "action", False: END})
        graph.add_edge("action", "llm")
        graph.set_entry_point("llm")
        self.graph = graph.compile(
            checkpointer=checkpointer,
            interrupt_before=["action"] ## Human in loop -- Manual Approval -- Before calling the tool
        )
        self.tools = {t.name: t for t in tools}
        self.model = model.bind_tools(tools)

    def call_openai(self, state: AgentState):
        messages = state['messages']
        if self.system:
            messages = [SystemMessage(content=self.system)] + messages
        message = self.model.invoke(messages)
        return {'messages': [message]}

    def exists_action(self, state: AgentState):
        print(state)
        result = state['messages'][-1]
        return len(result.tool_calls) > 0

    def take_action(self, state: AgentState):
        tool_calls = state['messages'][-1].tool_calls
        results = []
        for t in tool_calls:
            print(f"Calling: {t}")
            result = self.tools[t['name']].invoke(t['args'])
            results.append(ToolMessage(tool_call_id=t['id'], name=t['name'], content=str(result)))
        print("Back to the model!")
        return {'messages': results}

# %%
prompt = """You are a smart research assistant. Use the search engine to look up information. \
You are allowed to make multiple calls (either together or in sequence). \
Only look up information when you are sure of what you want. \
If you need to look up some information before asking a follow up question, you are allowed to do that!
"""
model = ChatOpenAI(model="gpt-3.5-turbo")
abot = Agent(model, [tool], system=prompt, checkpointer=memory)

# %%
messages = [HumanMessage(content="Whats the weather in SF?")]
thread = {"configurable": {"thread_id": "1"}}
for event in abot.graph.stream({"messages": messages}, thread):
    for v in event.values():
        print(v)
# Out:
# {'messages': [HumanMessage(content='Whats the weather in SF?', id='116567ee-d27f-4606-bded-7428d32fab8e'), AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_vaF9x6WKLMjgk06jyT8YERD3', 'function': {'arguments': '{"query":"current weather in San Francisco"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}]}, response_metadata={'token_usage': {'completion_tokens': 22, 'prompt_tokens': 152, 'total_tokens': 174}, 'model_name': 'gpt-3.5-turbo', 'system_fingerprint': None, 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-4450d439-afcf-4873-bb0c-e17d54909186-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'current weather in San Francisco'}, 'id': 'call_vaF9x6WKLMjgk06jyT8YERD3'}])]}
# {'messages': [AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_vaF9x6WKLMjgk06jyT8YERD3', 'function': {'arguments': '{"query":"current weather in San Francisco"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}]}, response_metadata={'token_usage': {'completion_tokens': 22, 'prompt_tokens': 152, 'total_tokens': 174}, 'model_name': 'gpt-3.5-turbo', 'system_fingerprint': None, 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-4450d439-afcf-4873-bb0c-e17d54909186-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'current weather in San Francisco'}, 'id': 'call_vaF9x6WKLMjgk06jyT8YERD3'}])]}

# %% [markdown]
# In above , Before calling tool . It is interupted

# %%
abot.graph.get_state(thread)
# Out:
# StateSnapshot(values={'messages': [HumanMessage(content='Whats the weather in SF?', id='116567ee-d27f-4606-bded-7428d32fab8e'), AIMessage(content='', additional_kwargs={'tool_calls': [{'function': {'arguments': '{"query":"current weather in San Francisco"}', 'name': 'tavily_search_results_json'}, 'id': 'call_vaF9x6WKLMjgk06jyT8YERD3', 'type': 'function'}]}, response_metadata={'finish_reason': 'tool_calls', 'logprobs': None, 'model_name': 'gpt-3.5-turbo', 'system_fingerprint': None, 'token_usage': {'completion_tokens': 22, 'prompt_tokens': 152, 'total_tokens': 174}}, id='run-4450d439-afcf-4873-bb0c-e17d54909186-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'current weather in San Francisco'}, 'id': 'call_vaF9x6WKLMjgk06jyT8YERD3'}])]}, next=('action',), config={'configurable': {'thread_id': '1', 'thread_ts': '1ef4b19f-9ed4-6c31-8001-4a283048faf9'}}, metadata={'source': 'loop', 'step': 1, 'writes': {'llm': {'messages': [AIMessage(content='', additional_kwargs={'tool_calls': [{'function': {'arguments': '{"query":"current weather in San Francisco"}', 'name': 'tavily_search_results_json'}, 'id': 'call_vaF9x6WKLMjgk06jyT8YERD3', 'type': 'function'}]}, response_metadata={'finish_reason': 'tool_calls', 'logprobs': None, 'model_name': 'gpt-3.5-turbo', 'system_fingerprint': None, 'token_usage': {'completion_tokens': 22, 'prompt_tokens': 152, 'total_tokens': 174}}, id='run-4450d439-afcf-4873-bb0c-e17d54909186-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'current weather in San Francisco'}, 'id': 'call_vaF9x6WKLMjgk06jyT8YERD3'}])]}}}, created_at='2024-07-26T06:40:41.111846+00:00', parent_config={'configurable': {'thread_id': '1', 'thread_ts': '1ef4b19f-98a3-6b58-8000-88fe81931f8b'}})

# %% [markdown]
# Node which is to be called next . We can get that with next . Check below

# %%
abot.graph.get_state(thread).next
# Out:
# ('action',)

# %% [markdown]
# ### continue after interrupt

# %%
for event in abot.graph.stream(None, thread):
    for v in event.values():
        print(v)
# Out:
# Calling: {'name': 'tavily_search_results_json', 'args': {'query': 'current weather in San Francisco'}, 'id': 'call_vaF9x6WKLMjgk06jyT8YERD3'}
# Back to the model!
# {'messages': [ToolMessage(content='[{\'url\': \'https://www.weatherapi.com/\', \'content\': "{\'location\': {\'name\': \'San Francisco\', \'region\': \'California\', \'country\': \'United States of America\', \'lat\': 37.78, \'lon\': -122.42, \'tz_id\': \'America/Los_Angeles\', \'localtime_epoch\': 1721975976, \'localtime\': \'2024-07-25 23:39\'}, \'current\': {\'last_updated_epoch\': 1721975400, \'last_updated\': \'2024-07-25 23:30\', \'temp_c\': 13.7, \'temp_f\': 56.7, \'is_day\': 0, \'condition\': {\'text\': \'Clear\', \'icon\': \'//cdn.weatherapi.com/weather/64x64/night/113.png\', \'code\': 1000}, \'wind_mph\': 8.1, \'wind_kph\': 13.0, \'wind_degree\': 247, \'wind_dir\': \'WSW\', \'pressure_mb\': 1016.0, \'pressure_in\': 30.0, \'precip_mm\': 0.0, \'precip_in\': 0.0, \'humidity\': 81, \'cloud\': 0, \'feelslike_c\': 12.7, \'feelslike_f\': 54.9, \'windchill_c\': 12.7, \'windchill_f\': 54.9, \'heatindex_c\': 13.7, \'heatindex_f\': 56.7, \'dewpoint_c\': 10.3, \'dewpoint_f\': 50.6, \'vis_km\': 10.0, \'vis_miles\': 6.0, \'uv\': 1.0, \'gust_mph\': 12.8, \'gust_kph\': 20.7}}"}, {\'url\': \'https://www.timeanddate.com/weather/usa/san-francisco/hourly\', \'content\': \'Hour-by-Hour Forecast for San Francisco, California, USA. Weather Today Weather Hourly 14 Day Forecast Yesterday/Past Weather Climate (Averages) Currently: 55 °F. Passing clouds. (Weather station: San Francisco International Airport, USA). See more current weather.\'}]', name='tavily_search_results_json', id='0336e359-3b1d-4467-9d50-51641da13367', tool_call_id='call_vaF9x6WKLMjgk06jyT8YERD3')]}
# {'messages': [HumanMessage(content='Whats the weather in SF?', id='116567ee-d27f-4606-bded-7428d32fab8e'), AIMessage(content='', additional_kwargs={'tool_calls': [{'function': {'arguments': '{"query":"current weather in San Francisco"}', 'name': 'tavily_search_results_json'}, 'id': 'call_vaF9x6WKLMjgk06jyT8YERD3', 'type': 'function'}]}, response_metadata={'finish_reason': 'tool_calls', 'logprobs': None, 'model_name': 'gpt-3.5-turbo', 'system_fingerprint': None, 'token_usage': {'completion_tokens': 22, 'prompt_tokens': 152, 'total_tokens': 174}}, id='run-4450d439-afcf-4873-bb0c-e17d54909186-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'current weather in San Francisco'}, 'id': 'call_vaF9x6WKLMjgk06jyT8YERD3'}]), ToolMessage(content='[{\'url\': \'https://www.weatherapi.com/\', \'content\': "{\'location\': {\'name\': \'San Francisco\', \'region\': \'California\', \'country\': \'United States of America\', \'lat\': 37.78, \'lon\': -122.42, \'tz_id\': \'America/Los_Angeles\', \'localtime_epoch\': 1721975976, \'localtime\': \'2024-07-25 23:39\'}, \'current\': {\'last_updated_epoch\': 1721975400, \'last_updated\': \'2024-07-25 23:30\', \'temp_c\': 13.7, \'temp_f\': 56.7, \'is_day\': 0, \'condition\': {\'text\': \'Clear\', \'icon\': \'//cdn.weatherapi.com/weather/64x64/night/113.png\', \'code\': 1000}, \'wind_mph\': 8.1, \'wind_kph\': 13.0, \'wind_degree\': 247, \'wind_dir\': \'WSW\', \'pressure_mb\': 1016.0, \'pressure_in\': 30.0, \'precip_mm\': 0.0, \'precip_in\': 0.0, \'humidity\': 81, \'cloud\': 0, \'feelslike_c\': 12.7, \'feelslike_f\': 54.9, \'windchill_c\': 12.7, \'windchill_f\': 54.9, \'heatindex_c\': 13.7, \'heatindex_f\': 56.7, \'dewpoint_c\': 10.3, \'dewpoint_f\': 50.6, \'vis_km\': 10.0, \'vis_miles\': 6.0, \'uv\': 1.0, \'gust_mph\': 12.8, \'gust_kph\': 20.7}}"}, {\'url\': \'https://www.timeanddate.com/weather/usa/san-francisco/hourly\', \'content\': \'Hour-by-Hour Forecast for San Francisco, California, USA. Weather Today Weather Hourly 14 Day Forecast Yesterday/Past Weather Climate (Averages) Currently: 55 °F. Passing clouds. (Weather station: San Francisco International Airport, USA). See more current weather.\'}]', name='tavily_search_results_json', id='0336e359-3b1d-4467-9d50-51641da13367', tool_call_id='call_vaF9x6WKLMjgk06jyT8YERD3'), AIMessage(content='The current weather in San Francisco is as follows:\n- Temperature: 56.7°F (13.7°C)\n- Condition: Clear\n- Wind: 8.1 mph from WSW\n- Humidity: 81%\n- Visibility: 6.0 miles\n- UV Index: 1.0\n\nIf you need more detailed information or hourly forecasts, I can look that up as well.', response_metadata={'token_usage': {'completion_tokens': 85, 'prompt_tokens': 679, 'total_tokens': 764}, 'model_name': 'gpt-3.5-turbo', 'system_fingerprint': None, 'finish_reason': 'stop', 'logprobs': None}, id='run-a38816ea-c7ea-478a-a88a-b918e32cf408-0')]}
# {'messages': [AIMessage(content='The current weather in San Francisco is as follows:\n- Temperature: 56.7°F (13.7°C)\n- Condition: Clear\n- Wind: 8.1 mph from WSW\n- Humidity: 81%\n- Visibility: 6.0 miles\n- UV Index: 1.0\n\nIf you need more detailed information or hourly forecasts, I can look that up as well.', response_metadata={'token_usage': {'completion_tokens': 85, 'prompt_tokens': 679, 'total_tokens': 764}, 'model_name': 'gpt-3.5-turbo', 'system_fingerprint': None, 'finish_reason': 'stop', 'logprobs': None}, id='run-a38816ea-c7ea-478a-a88a-b918e32cf408-0')]}

# %%
abot.graph.get_state(thread)
# Out:
# StateSnapshot(values={'messages': [HumanMessage(content='Whats the weather in SF?', id='116567ee-d27f-4606-bded-7428d32fab8e'), AIMessage(content='', additional_kwargs={'tool_calls': [{'function': {'arguments': '{"query":"current weather in San Francisco"}', 'name': 'tavily_search_results_json'}, 'id': 'call_vaF9x6WKLMjgk06jyT8YERD3', 'type': 'function'}]}, response_metadata={'finish_reason': 'tool_calls', 'logprobs': None, 'model_name': 'gpt-3.5-turbo', 'system_fingerprint': None, 'token_usage': {'completion_tokens': 22, 'prompt_tokens': 152, 'total_tokens': 174}}, id='run-4450d439-afcf-4873-bb0c-e17d54909186-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'current weather in San Francisco'}, 'id': 'call_vaF9x6WKLMjgk06jyT8YERD3'}]), ToolMessage(content='[{\'url\': \'https://www.weatherapi.com/\', \'content\': "{\'location\': {\'name\': \'San Francisco\', \'region\': \'California\', \'country\': \'United States of America\', \'lat\': 37.78, \'lon\': -122.42, \'tz_id\': \'America/Los_Angeles\', \'localtime_epoch\': 1721975976, \'localtime\': \'2024-07-25 23:39\'}, \'current\': {\'last_updated_epoch\': 1721975400, \'last_updated\': \'2024-07-25 23:30\', \'temp_c\': 13.7, \'temp_f\': 56.7, \'is_day\': 0, \'condition\': {\'text\': \'Clear\', \'icon\': \'//cdn.weatherapi.com/weather/64x64/night/113.png\', \'code\': 1000}, \'wind_mph\': 8.1, \'wind_kph\': 13.0, \'wind_degree\': 247, \'wind_dir\': \'WSW\', \'pressure_mb\': 1016.0, \'pressure_in\': 30.0, \'precip_mm\': 0.0, \'precip_in\': 0.0, \'humidity\': 81, \'cloud\': 0, \'feelslike_c\': 12.7, \'feelslike_f\': 54.9, \'windchill_c\': 12.7, \'windchill_f\': 54.9, \'heatindex_c\': 13.7, \'heatindex_f\': 56.7, \'dewpoint_c\': 10.3, \'dewpoint_f\': 50.6, \'vis_km\': 10.0, \'vis_miles\': 6.0, \'uv\': 1.0, \'gust_mph\': 12.8, \'gust_kph\': 20.7}}"}, {\'url\': \'https://www.timeanddate.com/weather/usa/san-francisco/hourly\', \'content\': \'Hour-by-Hour Forecast for San Francisco, California, USA. Weather Today Weather Hourly 14 Day Forecast Yesterday/Past Weather Climate (Averages) Currently: 55 °F. Passing clouds. (Weather station: San Francisco International Airport, USA). See more current weather.\'}]', name='tavily_search_results_json', id='0336e359-3b1d-4467-9d50-51641da13367', tool_call_id='call_vaF9x6WKLMjgk06jyT8YERD3'), AIMessage(content='The current weather in San Francisco is as follows:\n- Temperature: 56.7°F (13.7°C)\n- Condition: Clear\n- Wind: 8.1 mph from WSW\n- Humidity: 81%\n- Visibility: 6.0 miles\n- UV Index: 1.0\n\nIf you need more detailed information or hourly forecasts, I can look that up as well.', response_metadata={'finish_reason': 'stop', 'logprobs': None, 'model_name': 'gpt-3.5-turbo', 'system_fingerprint': None, 'token_usage': {'completion_tokens': 85, 'prompt_tokens': 679, 'total_tokens': 764}}, id='run-a38816ea-c7ea-478a-a88a-b918e32cf408-0')]}, next=(), config={'configurable': {'thread_id': '1', 'thread_ts': '1ef4b1a5-3797-616c-8003-c6fa456d62e9'}}, metadata={'source': 'loop', 'step': 3, 'writes': {'llm': {'messages': [AIMessage(content='The current weather in San Francisco is as follows:\n- Temperature: 56.7°F (13.7°C)\n- Condition: Clear\n- Wind: 8.1 mph from WSW\n- Humidity: 81%\n- Visibility: 6.0 miles\n- UV Index: 1.0\n\nIf you need more detailed information or hourly forecasts, I can look that up as well.', response_metadata={'finish_reason': 'stop', 'logprobs': None, 'model_name': 'gpt-3.5-turbo', 'system_fingerprint': None, 'token_usage': {'completion_tokens': 85, 'prompt_tokens': 679, 'total_tokens': 764}}, id='run-a38816ea-c7ea-478a-a88a-b918e32cf408-0')]}}}, created_at='2024-07-26T06:43:11.347520+00:00', parent_config={'configurable': {'thread_id': '1', 'thread_ts': '1ef4b1a5-2c1a-6f8e-8002-958a28d73aac'}})

# %%
abot.graph.get_state(thread).next
# Out:
# ()

# %% [markdown]
# Lets add above steps in loop , We will prompt user whether to continue or not

# %%
messages = [HumanMessage("Whats the weather in LA?")]
thread = {"configurable": {"thread_id": "3"}}
for event in abot.graph.stream({"messages": messages}, thread):
    for v in event.values():
        print(v)
while abot.graph.get_state(thread).next:
    print("\n", abot.graph.get_state(thread),"\n")
    _input = input("proceed?")
    if _input != "y":
        print("aborting")
        break
    for event in abot.graph.stream(None, thread):
        for v in event.values():
            print(v)
# Out:
# {'messages': [HumanMessage(content='Whats the weather in LA?', id='82fa1836-a494-4746-b1b6-35ba6a9c47ec'), AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_j77yb5ev1Yo1sf8yAM4QB8zi', 'function': {'arguments': '{"query":"weather in Los Angeles"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}]}, response_metadata={'token_usage': {'completion_tokens': 21, 'prompt_tokens': 152, 'total_tokens': 173}, 'model_name': 'gpt-3.5-turbo', 'system_fingerprint': None, 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-745d9e57-dfe5-41ac-9261-4e0cb7b2bb3d-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'weather in Los Angeles'}, 'id': 'call_j77yb5ev1Yo1sf8yAM4QB8zi'}])]}
# {'messages': [AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_j77yb5ev1Yo1sf8yAM4QB8zi', 'function': {'arguments': '{"query":"weather in Los Angeles"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}]}, response_metadata={'token_usage': {'completion_tokens': 21, 'prompt_tokens': 152, 'total_tokens': 173}, 'model_name': 'gpt-3.5-turbo', 'system_fingerprint': None, 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-745d9e57-dfe5-41ac-9261-4e0cb7b2bb3d-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'weather in Los Angeles'}, 'id': 'call_j77yb5ev1Yo1sf8yAM4QB8zi'}])]}
#
#  StateSnapshot(values={'messages': [HumanMessage(content='Whats the weather in LA?', id='82fa1836-a494-4746-b1b6-35ba6a9c47ec'), AIMessage(content='', additional_kwargs={'tool_calls': [{'function': {'arguments': '{"query":"weather in Los Angeles"}', 'name': 'tavily_search_results_json'}, 'id': 'call_j77yb5ev1Yo1sf8yAM4QB8zi', 'type': 'function'}]}, response_metadata={'finish_reason': 'tool_calls', 'logprobs': None, 'model_name': 'gpt-3.5-turbo', 'system_fingerprint': None, 'token_usage': {'completion_tokens': 21, 'prompt_tokens': 152, 'total_tokens': 173}}, id='run-745d9e57-dfe5-41ac-9261-4e0cb7b2bb3d-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'weather in Los Angeles'}, 'id': 'call_j77yb5ev1Yo1sf8yAM4QB8zi'}])]}, next=('action',), config={'configurable': {'thread_id': '3', 'thread_ts': '1ef4b1aa-190d-6658-8001-ffb386c975d7'}}, metadata={'source': 'loop', 'step': 1, 'writes': {'llm': {'messages': [AIMessage(content='', additional_kwargs={'tool_calls': [{'function': {'arguments': '{"query":"weather in Los Angeles"}', 'name': 'tavily_search_results_json'}, 'id': 'call_j77yb5ev1Yo1sf8yAM4QB8zi', 'type': 'function'}]}, response_metadata={'finish_reason': 'tool_calls', 'logprobs': None, 'model_name': 'gpt-3.5-turbo', 'system_fingerprint': None, 'token_usage': {'completion_tokens': 21, 'prompt_tokens': 152, 'total_tokens': 173}}, id='run-745d9e57-dfe5-41ac-9261-4e0cb7b2bb3d-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'weather in Los Angeles'}, 'id': 'call_j77yb5ev1Yo1sf8yAM4QB8zi'}])]}}}, created_at='2024-07-26T06:45:22.363127+00:00', parent_config={'configurable': {'thread_id': '3', 'thread_ts': '1ef4b1aa-13f1-6f02-8000-cb4b081cd0a5'}})
#
# proceed?y
# Calling: {'name': 'tavily_search_results_json', 'args': {'query': 'weather in Los Angeles'}, 'id': 'call_j77yb5ev1Yo1sf8yAM4QB8zi'}
# Back to the model!
# {'messages': [ToolMessage(content='[{\'url\': \'https://www.weatherapi.com/\', \'content\': "{\'location\': {\'name\': \'Los Angeles\', \'region\': \'California\', \'country\': \'United States of America\', \'lat\': 34.05, \'lon\': -118.24, \'tz_id\': \'America/Los_Angeles\', \'localtime_epoch\': 1721976244, \'localtime\': \'2024-07-25 23:44\'}, \'current\': {\'last_updated_epoch\': 1721975400, \'last_updated\': \'2024-07-25 23:30\', \'temp_c\': 25.3, \'temp_f\': 77.5, \'is_day\': 0, \'condition\': {\'text\': \'Clear\', \'icon\': \'//cdn.weatherapi.com/weather/64x64/night/113.png\', \'code\': 1000}, \'wind_mph\': 4.7, \'wind_kph\': 7.6, \'wind_degree\': 156, \'wind_dir\': \'SSE\', \'pressure_mb\': 1014.0, \'pressure_in\': 29.94, \'precip_mm\': 0.0, \'precip_in\': 0.0, \'humidity\': 52, \'cloud\': 3, \'feelslike_c\': 26.2, \'feelslike_f\': 79.1, \'windchill_c\': 25.3, \'windchill_f\': 77.5, \'heatindex_c\': 26.2, \'heatindex_f\': 79.1, \'dewpoint_c\': 14.8, \'dewpoint_f\': 58.6, \'vis_km\': 10.0, \'vis_miles\': 6.0, \'uv\': 1.0, \'gust_mph\': 6.3, \'gust_kph\': 10.1}}"}, {\'url\': \'https://world-weather.info/forecast/usa/los_angeles/july-2024/\', \'content\': \'Extended weather forecast in Los Angeles. Hourly Week 10 days 14 days 30 days Year. Detailed ⚡ Los Angeles Weather Forecast for July 2024 - day/night 🌡️ temperatures, precipitations - World-Weather.info.\'}]', name='tavily_search_results_json', id='62fb0776-471a-4312-8aa8-7700557e6799', tool_call_id='call_j77yb5ev1Yo1sf8yAM4QB8zi')]}
# {'messages': [HumanMessage(content='Whats the weather in LA?', id='82fa1836-a494-4746-b1b6-35ba6a9c47ec'), AIMessage(content='', additional_kwargs={'tool_calls': [{'function': {'arguments': '{"query":"weather in Los Angeles"}', 'name': 'tavily_search_results_json'}, 'id': 'call_j77yb5ev1Yo1sf8yAM4QB8zi', 'type': 'function'}]}, response_metadata={'finish_reason': 'tool_calls', 'logprobs': None, 'model_name': 'gpt-3.5-turbo', 'system_fingerprint': None, 'token_usage': {'completion_tokens': 21, 'prompt_tokens': 152, 'total_tokens': 173}}, id='run-745d9e57-dfe5-41ac-9261-4e0cb7b2bb3d-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'weather in Los Angeles'}, 'id': 'call_j77yb5ev1Yo1sf8yAM4QB8zi'}]), ToolMessage(content='[{\'url\': \'https://www.weatherapi.com/\', \'content\': "{\'location\': {\'name\': \'Los Angeles\', \'region\': \'California\', \'country\': \'United States of America\', \'lat\': 34.05, \'lon\': -118.24, \'tz_id\': \'America/Los_Angeles\', \'localtime_epoch\': 1721976244, \'localtime\': \'2024-07-25 23:44\'}, \'current\': {\'last_updated_epoch\': 1721975400, \'last_updated\': \'2024-07-25 23:30\', \'temp_c\': 25.3, \'temp_f\': 77.5, \'is_day\': 0, \'condition\': {\'text\': \'Clear\', \'icon\': \'//cdn.weatherapi.com/weather/64x64/night/113.png\', \'code\': 1000}, \'wind_mph\': 4.7, \'wind_kph\': 7.6, \'wind_degree\': 156, \'wind_dir\': \'SSE\', \'pressure_mb\': 1014.0, \'pressure_in\': 29.94, \'precip_mm\': 0.0, \'precip_in\': 0.0, \'humidity\': 52, \'cloud\': 3, \'feelslike_c\': 26.2, \'feelslike_f\': 79.1, \'windchill_c\': 25.3, \'windchill_f\': 77.5, \'heatindex_c\': 26.2, \'heatindex_f\': 79.1, \'dewpoint_c\': 14.8, \'dewpoint_f\': 58.6, \'vis_km\': 10.0, \'vis_miles\': 6.0, \'uv\': 1.0, \'gust_mph\': 6.3, \'gust_kph\': 10.1}}"}, {\'url\': \'https://world-weather.info/forecast/usa/los_angeles/july-2024/\', \'content\': \'Extended weather forecast in Los Angeles. Hourly Week 10 days 14 days 30 days Year. Detailed ⚡ Los Angeles Weather Forecast for July 2024 - day/night 🌡️ temperatures, precipitations - World-Weather.info.\'}]', name='tavily_search_results_json', id='62fb0776-471a-4312-8aa8-7700557e6799', tool_call_id='call_j77yb5ev1Yo1sf8yAM4QB8zi'), AIMessage(content='The current weather in Los Angeles is as follows:\n- Temperature: 25.3°C (77.5°F)\n- Condition: Clear\n- Wind: 7.6 km/h SSE\n- Pressure: 1014.0 mb\n- Humidity: 52%\n- Visibility: 10.0 km\n- UV Index: 1.0\n\nFor more detailed and extended weather forecast, you can visit [World-Weather.info](https://world-weather.info/forecast/usa/los_angeles/july-2024/).', response_metadata={'token_usage': {'completion_tokens': 115, 'prompt_tokens': 675, 'total_tokens': 790}, 'model_name': 'gpt-3.5-turbo', 'system_fingerprint': None, 'finish_reason': 'stop', 'logprobs': None}, id='run-c6c78488-6797-484f-a773-c5a660d3c841-0')]}
# {'messages': [AIMessage(content='The current weather in Los Angeles is as follows:\n- Temperature: 25.3°C (77.5°F)\n- Condition: Clear\n- Wind: 7.6 km/h SSE\n- Pressure: 1014.0 mb\n- Humidity: 52%\n- Visibility: 10.0 km\n- UV Index: 1.0\n\nFor more detailed and extended weather forecast, you can visit [World-Weather.info](https://world-weather.info/forecast/usa/los_angeles/july-2024/).', response_metadata={'token_usage': {'completion_tokens': 115, 'prompt_tokens': 675, 'total_tokens': 790}, 'model_name': 'gpt-3.5-turbo', 'system_fingerprint': None, 'finish_reason': 'stop', 'logprobs': None}, id='run-c6c78488-6797-484f-a773-c5a660d3c841-0')]}

# %% [markdown]
# #### State Memory
#
# As the graph is executing , Snapshot of each step is stored in memory .
#
# ![image.png](attachment:image.png)

# %% [markdown]
# we can use thread id to access the snapshot
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Time travel to specific state again
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Modify state and store its snapshot again in memory
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ## Modify State
# Run until the interrupt and then modify the state.

# %%
messages = [HumanMessage("Whats the weather in LA?")]
thread = {"configurable": {"thread_id": "4"}}
for event in abot.graph.stream({"messages": messages}, thread):
    for v in event.values():
        print(v)
# Out:
# {'messages': [HumanMessage(content='Whats the weather in LA?', id='bf5d2a38-d276-4d0e-ac0f-a9e7ad4f75a4'), AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_a5ZiWId9TSjjm5t3BDlNmGPA', 'function': {'arguments': '{"query":"weather in Los Angeles"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}]}, response_metadata={'token_usage': {'completion_tokens': 21, 'prompt_tokens': 152, 'total_tokens': 173}, 'model_name': 'gpt-3.5-turbo', 'system_fingerprint': None, 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-13f6de6b-b563-46b5-b140-b7513611a80a-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'weather in Los Angeles'}, 'id': 'call_a5ZiWId9TSjjm5t3BDlNmGPA'}])]}
# {'messages': [AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_a5ZiWId9TSjjm5t3BDlNmGPA', 'function': {'arguments': '{"query":"weather in Los Angeles"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}]}, response_metadata={'token_usage': {'completion_tokens': 21, 'prompt_tokens': 152, 'total_tokens': 173}, 'model_name': 'gpt-3.5-turbo', 'system_fingerprint': None, 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-13f6de6b-b563-46b5-b140-b7513611a80a-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'weather in Los Angeles'}, 'id': 'call_a5ZiWId9TSjjm5t3BDlNmGPA'}])]}

# %%
abot.graph.get_state(thread)
# Out:
# StateSnapshot(values={'messages': [HumanMessage(content='Whats the weather in LA?', id='bf5d2a38-d276-4d0e-ac0f-a9e7ad4f75a4'), AIMessage(content='', additional_kwargs={'tool_calls': [{'function': {'arguments': '{"query":"weather in Los Angeles"}', 'name': 'tavily_search_results_json'}, 'id': 'call_a5ZiWId9TSjjm5t3BDlNmGPA', 'type': 'function'}]}, response_metadata={'finish_reason': 'tool_calls', 'logprobs': None, 'model_name': 'gpt-3.5-turbo', 'system_fingerprint': None, 'token_usage': {'completion_tokens': 21, 'prompt_tokens': 152, 'total_tokens': 173}}, id='run-13f6de6b-b563-46b5-b140-b7513611a80a-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'weather in Los Angeles'}, 'id': 'call_a5ZiWId9TSjjm5t3BDlNmGPA'}])]}, next=('action',), config={'configurable': {'thread_id': '4', 'thread_ts': '1ef4b1b5-d983-62d3-8001-45142cf66e95'}}, metadata={'source': 'loop', 'step': 1, 'writes': {'llm': {'messages': [AIMessage(content='', additional_kwargs={'tool_calls': [{'function': {'arguments': '{"query":"weather in Los Angeles"}', 'name': 'tavily_search_results_json'}, 'id': 'call_a5ZiWId9TSjjm5t3BDlNmGPA', 'type': 'function'}]}, response_metadata={'finish_reason': 'tool_calls', 'logprobs': None, 'model_name': 'gpt-3.5-turbo', 'system_fingerprint': None, 'token_usage': {'completion_tokens': 21, 'prompt_tokens': 152, 'total_tokens': 173}}, id='run-13f6de6b-b563-46b5-b140-b7513611a80a-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'weather in Los Angeles'}, 'id': 'call_a5ZiWId9TSjjm5t3BDlNmGPA'}])]}}}, created_at='2024-07-26T06:50:37.823030+00:00', parent_config={'configurable': {'thread_id': '4', 'thread_ts': '1ef4b1b5-d282-6568-8000-1f45df80a00f'}})

# %%
current_values = abot.graph.get_state(thread)

# %%
current_values.values['messages'][-1]
# Out:
# AIMessage(content='', additional_kwargs={'tool_calls': [{'function': {'arguments': '{"query":"weather in Los Angeles"}', 'name': 'tavily_search_results_json'}, 'id': 'call_a5ZiWId9TSjjm5t3BDlNmGPA', 'type': 'function'}]}, response_metadata={'finish_reason': 'tool_calls', 'logprobs': None, 'model_name': 'gpt-3.5-turbo', 'system_fingerprint': None, 'token_usage': {'completion_tokens': 21, 'prompt_tokens': 152, 'total_tokens': 173}}, id='run-13f6de6b-b563-46b5-b140-b7513611a80a-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'weather in Los Angeles'}, 'id': 'call_a5ZiWId9TSjjm5t3BDlNmGPA'}])

# %%
current_values.values['messages'][-1].tool_calls
# Out:
# [{'name': 'tavily_search_results_json',
#   'args': {'query': 'weather in Los Angeles'},
#   'id': 'call_a5ZiWId9TSjjm5t3BDlNmGPA'}]

# %%
_id = current_values.values['messages'][-1].tool_calls[0]['id']
current_values.values['messages'][-1].tool_calls = [
    {'name': 'tavily_search_results_json',
  'args': {'query': 'current weather in Louisiana'},
  'id': _id}
]

# %%
abot.graph.update_state(thread, current_values.values)
# Out:
# {'messages': [HumanMessage(content='Whats the weather in LA?', id='bf5d2a38-d276-4d0e-ac0f-a9e7ad4f75a4'), AIMessage(content='', additional_kwargs={'tool_calls': [{'function': {'arguments': '{"query":"weather in Los Angeles"}', 'name': 'tavily_search_results_json'}, 'id': 'call_a5ZiWId9TSjjm5t3BDlNmGPA', 'type': 'function'}]}, response_metadata={'finish_reason': 'tool_calls', 'logprobs': None, 'model_name': 'gpt-3.5-turbo', 'system_fingerprint': None, 'token_usage': {'completion_tokens': 21, 'prompt_tokens': 152, 'total_tokens': 173}}, id='run-13f6de6b-b563-46b5-b140-b7513611a80a-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'current weather in Louisiana'}, 'id': 'call_a5ZiWId9TSjjm5t3BDlNmGPA'}])]}
# {'configurable': {'thread_id': '4',
#   'thread_ts': '1ef4b1b9-ca9e-6779-8002-aa29e8bfe228'}}

# %%
abot.graph.get_state(thread)
# Out:
# StateSnapshot(values={'messages': [HumanMessage(content='Whats the weather in LA?', id='bf5d2a38-d276-4d0e-ac0f-a9e7ad4f75a4'), AIMessage(content='', additional_kwargs={'tool_calls': [{'function': {'arguments': '{"query":"weather in Los Angeles"}', 'name': 'tavily_search_results_json'}, 'id': 'call_a5ZiWId9TSjjm5t3BDlNmGPA', 'type': 'function'}]}, response_metadata={'finish_reason': 'tool_calls', 'logprobs': None, 'model_name': 'gpt-3.5-turbo', 'system_fingerprint': None, 'token_usage': {'completion_tokens': 21, 'prompt_tokens': 152, 'total_tokens': 173}}, id='run-13f6de6b-b563-46b5-b140-b7513611a80a-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'current weather in Louisiana'}, 'id': 'call_a5ZiWId9TSjjm5t3BDlNmGPA'}])]}, next=('action',), config={'configurable': {'thread_id': '4', 'thread_ts': '1ef4b1b9-ca9e-6779-8002-aa29e8bfe228'}}, metadata={'source': 'update', 'step': 2, 'writes': {'llm': {'messages': [HumanMessage(content='Whats the weather in LA?', id='bf5d2a38-d276-4d0e-ac0f-a9e7ad4f75a4'), AIMessage(content='', additional_kwargs={'tool_calls': [{'function': {'arguments': '{"query":"weather in Los Angeles"}', 'name': 'tavily_search_results_json'}, 'id': 'call_a5ZiWId9TSjjm5t3BDlNmGPA', 'type': 'function'}]}, response_metadata={'finish_reason': 'tool_calls', 'logprobs': None, 'model_name': 'gpt-3.5-turbo', 'system_fingerprint': None, 'token_usage': {'completion_tokens': 21, 'prompt_tokens': 152, 'total_tokens': 173}}, id='run-13f6de6b-b563-46b5-b140-b7513611a80a-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'current weather in Louisiana'}, 'id': 'call_a5ZiWId9TSjjm5t3BDlNmGPA'}])]}}}, created_at='2024-07-26T06:52:23.635526+00:00', parent_config={'configurable': {'thread_id': '4', 'thread_ts': '1ef4b1b5-d983-62d3-8001-45142cf66e95'}})

# %%
for event in abot.graph.stream(None, thread):
    for v in event.values():
        print(v)
# Out:
# Calling: {'name': 'tavily_search_results_json', 'args': {'query': 'current weather in Louisiana'}, 'id': 'call_a5ZiWId9TSjjm5t3BDlNmGPA'}
# Back to the model!
# {'messages': [ToolMessage(content='[{\'url\': \'https://www.weatherapi.com/\', \'content\': "{\'location\': {\'name\': \'Louisiana\', \'region\': \'Missouri\', \'country\': \'USA United States of America\', \'lat\': 39.44, \'lon\': -91.06, \'tz_id\': \'America/Chicago\', \'localtime_epoch\': 1721976678, \'localtime\': \'2024-07-26 1:51\'}, \'current\': {\'last_updated_epoch\': 1721976300, \'last_updated\': \'2024-07-26 01:45\', \'temp_c\': 20.3, \'temp_f\': 68.5, \'is_day\': 0, \'condition\': {\'text\': \'Partly Cloudy\', \'icon\': \'//cdn.weatherapi.com/weather/64x64/night/116.png\', \'code\': 1003}, \'wind_mph\': 8.7, \'wind_kph\': 14.0, \'wind_degree\': 89, \'wind_dir\': \'E\', \'pressure_mb\': 1020.0, \'pressure_in\': 30.13, \'precip_mm\': 0.0, \'precip_in\': 0.0, \'humidity\': 97, \'cloud\': 33, \'feelslike_c\': 20.3, \'feelslike_f\': 68.5, \'windchill_c\': 20.3, \'windchill_f\': 68.5, \'heatindex_c\': 20.6, \'heatindex_f\': 69.1, \'dewpoint_c\': 19.8, \'dewpoint_f\': 67.7, \'vis_km\': 10.0, \'vis_miles\': 6.0, \'uv\': 1.0, \'gust_mph\': 16.3, \'gust_kph\': 26.2}}"}, {\'url\': \'https://tgftp.nws.noaa.gov/weather/current/KLFT.html\', \'content\': \'Current Weather Conditions: LAFAYETTE REGIONAL AIRPORT, LA, United States ... KLFT 160453Z AUTO 00000KT 10SM CLR 26/24 A3000 RMK AO2 SLP159 T02560239 Maximum and Minimum Temperatures: Maximum Temperature F (C) Minimum Temperature F (C) 95.0 (35.0) 73.0 (22.8) In the 6 hours preceding Jul 15, 2024 - 07:53 PM EDT / 2024.07.15 2353 UTC : 93.0 (33. ...\'}]', name='tavily_search_results_json', id='5afd28f7-16d6-4d3a-8b46-a33483da8889', tool_call_id='call_a5ZiWId9TSjjm5t3BDlNmGPA')]}
# {'messages': [HumanMessage(content='Whats the weather in LA?', id='bf5d2a38-d276-4d0e-ac0f-a9e7ad4f75a4'), AIMessage(content='', additional_kwargs={'tool_calls': [{'function': {'arguments': '{"query":"weather in Los Angeles"}', 'name': 'tavily_search_results_json'}, 'id': 'call_a5ZiWId9TSjjm5t3BDlNmGPA', 'type': 'function'}]}, response_metadata={'finish_reason': 'tool_calls', 'logprobs': None, 'model_name': 'gpt-3.5-turbo', 'system_fingerprint': None, 'token_usage': {'completion_tokens': 21, 'prompt_tokens': 152, 'total_tokens': 173}}, id='run-13f6de6b-b563-46b5-b140-b7513611a80a-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'current weather in Louisiana'}, 'id': 'call_a5ZiWId9TSjjm5t3BDlNmGPA'}]), ToolMessage(content='[{\'url\': \'https://www.weatherapi.com/\', \'content\': "{\'location\': {\'name\': \'Louisiana\', \'region\': \'Missouri\', \'country\': \'USA United States of America\', \'lat\': 39.44, \'lon\': -91.06, \'tz_id\': \'America/Chicago\', \'localtime_epoch\': 1721976678, \'localtime\': \'2024-07-26 1:51\'}, \'current\': {\'last_updated_epoch\': 1721976300, \'last_updated\': \'2024-07-26 01:45\', \'temp_c\': 20.3, \'temp_f\': 68.5, \'is_day\': 0, \'condition\': {\'text\': \'Partly Cloudy\', \'icon\': \'//cdn.weatherapi.com/weather/64x64/night/116.png\', \'code\': 1003}, \'wind_mph\': 8.7, \'wind_kph\': 14.0, \'wind_degree\': 89, \'wind_dir\': \'E\', \'pressure_mb\': 1020.0, \'pressure_in\': 30.13, \'precip_mm\': 0.0, \'precip_in\': 0.0, \'humidity\': 97, \'cloud\': 33, \'feelslike_c\': 20.3, \'feelslike_f\': 68.5, \'windchill_c\': 20.3, \'windchill_f\': 68.5, \'heatindex_c\': 20.6, \'heatindex_f\': 69.1, \'dewpoint_c\': 19.8, \'dewpoint_f\': 67.7, \'vis_km\': 10.0, \'vis_miles\': 6.0, \'uv\': 1.0, \'gust_mph\': 16.3, \'gust_kph\': 26.2}}"}, {\'url\': \'https://tgftp.nws.noaa.gov/weather/current/KLFT.html\', \'content\': \'Current Weather Conditions: LAFAYETTE REGIONAL AIRPORT, LA, United States ... KLFT 160453Z AUTO 00000KT 10SM CLR 26/24 A3000 RMK AO2 SLP159 T02560239 Maximum and Minimum Temperatures: Maximum Temperature F (C) Minimum Temperature F (C) 95.0 (35.0) 73.0 (22.8) In the 6 hours preceding Jul 15, 2024 - 07:53 PM EDT / 2024.07.15 2353 UTC : 93.0 (33. ...\'}]', name='tavily_search_results_json', id='5afd28f7-16d6-4d3a-8b46-a33483da8889', tool_call_id='call_a5ZiWId9TSjjm5t3BDlNmGPA'), AIMessage(content='I found information on the current weather in Louisiana. The temperature is 20.3°C (68.5°F) with partly cloudy conditions. The wind speed is 14.0 kph coming from the east. The humidity is at 97%, and there is no precipitation at the moment.', response_metadata={'token_usage': {'completion_tokens': 61, 'prompt_tokens': 749, 'total_tokens': 810}, 'model_name': 'gpt-3.5-turbo', 'system_fingerprint': None, 'finish_reason': 'stop', 'logprobs': None}, id='run-7aee51f6-07b5-44e3-80cb-8dea2f01b527-0')]}
# {'messages': [AIMessage(content='I found information on the current weather in Louisiana. The temperature is 20.3°C (68.5°F) with partly cloudy conditions. The wind speed is 14.0 kph coming from the east. The humidity is at 97%, and there is no precipitation at the moment.', response_metadata={'token_usage': {'completion_tokens': 61, 'prompt_tokens': 749, 'total_tokens': 810}, 'model_name': 'gpt-3.5-turbo', 'system_fingerprint': None, 'finish_reason': 'stop', 'logprobs': None}, id='run-7aee51f6-07b5-44e3-80cb-8dea2f01b527-0')]}

# %% [markdown]
# ## Time Travel

# %%
states = []
for state in abot.graph.get_state_history(thread):
    print(state)
    print('--')
    states.append(state)
# Out:
# StateSnapshot(values={'messages': [HumanMessage(content='Whats the weather in LA?', id='bf5d2a38-d276-4d0e-ac0f-a9e7ad4f75a4'), AIMessage(content='', additional_kwargs={'tool_calls': [{'function': {'arguments': '{"query":"weather in Los Angeles"}', 'name': 'tavily_search_results_json'}, 'id': 'call_a5ZiWId9TSjjm5t3BDlNmGPA', 'type': 'function'}]}, response_metadata={'finish_reason': 'tool_calls', 'logprobs': None, 'model_name': 'gpt-3.5-turbo', 'system_fingerprint': None, 'token_usage': {'completion_tokens': 21, 'prompt_tokens': 152, 'total_tokens': 173}}, id='run-13f6de6b-b563-46b5-b140-b7513611a80a-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'current weather in Louisiana'}, 'id': 'call_a5ZiWId9TSjjm5t3BDlNmGPA'}]), ToolMessage(content='[{\'url\': \'https://www.weatherapi.com/\', \'content\': "{\'location\': {\'name\': \'Louisiana\', \'region\': \'Missouri\', \'country\': \'USA United States of America\', \'lat\': 39.44, \'lon\': -91.06, \'tz_id\': \'America/Chicago\', \'localtime_epoch\': 1721976678, \'localtime\': \'2024-07-26 1:51\'}, \'current\': {\'last_updated_epoch\': 1721976300, \'last_updated\': \'2024-07-26 01:45\', \'temp_c\': 20.3, \'temp_f\': 68.5, \'is_day\': 0, \'condition\': {\'text\': \'Partly Cloudy\', \'icon\': \'//cdn.weatherapi.com/weather/64x64/night/116.png\', \'code\': 1003}, \'wind_mph\': 8.7, \'wind_kph\': 14.0, \'wind_degree\': 89, \'wind_dir\': \'E\', \'pressure_mb\': 1020.0, \'pressure_in\': 30.13, \'precip_mm\': 0.0, \'precip_in\': 0.0, \'humidity\': 97, \'cloud\': 33, \'feelslike_c\': 20.3, \'feelslike_f\': 68.5, \'windchill_c\': 20.3, \'windchill_f\': 68.5, \'heatindex_c\': 20.6, \'heatindex_f\': 69.1, \'dewpoint_c\': 19.8, \'dewpoint_f\': 67.7, \'vis_km\': 10.0, \'vis_miles\': 6.0, \'uv\': 1.0, \'gust_mph\': 16.3, \'gust_kph\': 26.2}}"}, {\'url\': \'https://tgftp.nws.noaa.gov/weather/current/KLFT.html\', \'content\': \'Current Weather Conditions: LAFAYETTE REGIONAL AIRPORT, LA, United States ... KLFT 160453Z AUTO 00000KT 10SM CLR 26/24 A3000 RMK AO2 SLP159 T02560239 Maximum and Minimum Temperatures: Maximum Temperature F (C) Minimum Temperature F (C) 95.0 (35.0) 73.0 (22.8) In the 6 hours preceding Jul 15, 2024 - 07:53 PM EDT / 2024.07.15 2353 UTC : 93.0 (33. ...\'}]', name='tavily_search_results_json', id='5afd28f7-16d6-4d3a-8b46-a33483da8889', tool_call_id='call_a5ZiWId9TSjjm5t3BDlNmGPA'), AIMessage(content='I found information on the current weather in Louisiana. The temperature is 20.3°C (68.5°F) with partly cloudy conditions. The wind speed is 14.0 kph coming from the east. The humidity is at 97%, and there is no precipitation at the moment.', response_metadata={'finish_reason': 'stop', 'logprobs': None, 'model_name': 'gpt-3.5-turbo', 'system_fingerprint': None, 'token_usage': {'completion_tokens': 61, 'prompt_tokens': 749, 'total_tokens': 810}}, id='run-7aee51f6-07b5-44e3-80cb-8dea2f01b527-0')]}, next=(), config={'configurable': {'thread_id': '4', 'thread_ts': '1ef4b1ba-8687-6928-8004-0b1298840ff1'}}, metadata={'source': 'loop', 'step': 4, 'writes': {'llm': {'messages': [AIMessage(content='I found information on the current weather in Louisiana. The temperature is 20.3°C (68.5°F) with partly cloudy conditions. The wind speed is 14.0 kph coming from the east. The humidity is at 97%, and there is no precipitation at the moment.', response_metadata={'finish_reason': 'stop', 'logprobs': None, 'model_name': 'gpt-3.5-turbo', 'system_fingerprint': None, 'token_usage': {'completion_tokens': 61, 'prompt_tokens': 749, 'total_tokens': 810}}, id='run-7aee51f6-07b5-44e3-80cb-8dea2f01b527-0')]}}}, created_at='2024-07-26T06:52:43.339375+00:00', parent_config={'configurable': {'thread_id': '4', 'thread_ts': '1ef4b1ba-7a9b-63b1-8003-46b7e94df2b9'}})
# --
# StateSnapshot(values={'messages': [HumanMessage(content='Whats the weather in LA?', id='bf5d2a38-d276-4d0e-ac0f-a9e7ad4f75a4'), AIMessage(content='', additional_kwargs={'tool_calls': [{'function': {'arguments': '{"query":"weather in Los Angeles"}', 'name': 'tavily_search_results_json'}, 'id': 'call_a5ZiWId9TSjjm5t3BDlNmGPA', 'type': 'function'}]}, response_metadata={'finish_reason': 'tool_calls', 'logprobs': None, 'model_name': 'gpt-3.5-turbo', 'system_fingerprint': None, 'token_usage': {'completion_tokens': 21, 'prompt_tokens': 152, 'total_tokens': 173}}, id='run-13f6de6b-b563-46b5-b140-b7513611a80a-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'current weather in Louisiana'}, 'id': 'call_a5ZiWId9TSjjm5t3BDlNmGPA'}]), ToolMessage(content='[{\'url\': \'https://www.weatherapi.com/\', \'content\': "{\'location\': {\'name\': \'Louisiana\', \'region\': \'Missouri\', \'country\': \'USA United States of America\', \'lat\': 39.44, \'lon\': -91.06, \'tz_id\': \'America/Chicago\', \'localtime_epoch\': 1721976678, \'localtime\': \'2024-07-26 1:51\'}, \'current\': {\'last_updated_epoch\': 1721976300, \'last_updated\': \'2024-07-26 01:45\', \'temp_c\': 20.3, \'temp_f\': 68.5, \'is_day\': 0, \'condition\': {\'text\': \'Partly Cloudy\', \'icon\': \'//cdn.weatherapi.com/weather/64x64/night/116.png\', \'code\': 1003}, \'wind_mph\': 8.7, \'wind_kph\': 14.0, \'wind_degree\': 89, \'wind_dir\': \'E\', \'pressure_mb\': 1020.0, \'pressure_in\': 30.13, \'precip_mm\': 0.0, \'precip_in\': 0.0, \'humidity\': 97, \'cloud\': 33, \'feelslike_c\': 20.3, \'feelslike_f\': 68.5, \'windchill_c\': 20.3, \'windchill_f\': 68.5, \'heatindex_c\': 20.6, \'heatindex_f\': 69.1, \'dewpoint_c\': 19.8, \'dewpoint_f\': 67.7, \'vis_km\': 10.0, \'vis_miles\': 6.0, \'uv\': 1.0, \'gust_mph\': 16.3, \'gust_kph\': 26.2}}"}, {\'url\': \'https://tgftp.nws.noaa.gov/weather/current/KLFT.html\', \'content\': \'Current Weather Conditions: LAFAYETTE REGIONAL AIRPORT, LA, United States ... KLFT 160453Z AUTO 00000KT 10SM CLR 26/24 A3000 RMK AO2 SLP159 T02560239 Maximum and Minimum Temperatures: Maximum Temperature F (C) Minimum Temperature F (C) 95.0 (35.0) 73.0 (22.8) In the 6 hours preceding Jul 15, 2024 - 07:53 PM EDT / 2024.07.15 2353 UTC : 93.0 (33. ...\'}]', name='tavily_search_results_json', id='5afd28f7-16d6-4d3a-8b46-a33483da8889', tool_call_id='call_a5ZiWId9TSjjm5t3BDlNmGPA')]}, next=('llm',), config={'configurable': {'thread_id': '4', 'thread_ts': '1ef4b1ba-7a9b-63b1-8003-46b7e94df2b9'}}, metadata={'source': 'loop', 'step': 3, 'writes': {'action': {'messages': [ToolMessage(content='[{\'url\': \'https://www.weatherapi.com/\', \'content\': "{\'location\': {\'name\': \'Louisiana\', \'region\': \'Missouri\', \'country\': \'USA United States of America\', \'lat\': 39.44, \'lon\': -91.06, \'tz_id\': \'America/Chicago\', \'localtime_epoch\': 1721976678, \'localtime\': \'2024-07-26 1:51\'}, \'current\': {\'last_updated_epoch\': 1721976300, \'last_updated\': \'2024-07-26 01:45\', \'temp_c\': 20.3, \'temp_f\': 68.5, \'is_day\': 0, \'condition\': {\'text\': \'Partly Cloudy\', \'icon\': \'//cdn.weatherapi.com/weather/64x64/night/116.png\', \'code\': 1003}, \'wind_mph\': 8.7, \'wind_kph\': 14.0, \'wind_degree\': 89, \'wind_dir\': \'E\', \'pressure_mb\': 1020.0, \'pressure_in\': 30.13, \'precip_mm\': 0.0, \'precip_in\': 0.0, \'humidity\': 97, \'cloud\': 33, \'feelslike_c\': 20.3, \'feelslike_f\': 68.5, \'windchill_c\': 20.3, \'windchill_f\': 68.5, \'heatindex_c\': 20.6, \'heatindex_f\': 69.1, \'dewpoint_c\': 19.8, \'dewpoint_f\': 67.7, \'vis_km\': 10.0, \'vis_miles\': 6.0, \'uv\': 1.0, \'gust_mph\': 16.3, \'gust_kph\': 26.2}}"}, {\'url\': \'https://tgftp.nws.noaa.gov/weather/current/KLFT.html\', \'content\': \'Current Weather Conditions: LAFAYETTE REGIONAL AIRPORT, LA, United States ... KLFT 160453Z AUTO 00000KT 10SM CLR 26/24 A3000 RMK AO2 SLP159 T02560239 Maximum and Minimum Temperatures: Maximum Temperature F (C) Minimum Temperature F (C) 95.0 (35.0) 73.0 (22. ...
# --
# StateSnapshot(values={'messages': [HumanMessage(content='Whats the weather in LA?', id='bf5d2a38-d276-4d0e-ac0f-a9e7ad4f75a4'), AIMessage(content='', additional_kwargs={'tool_calls': [{'function': {'arguments': '{"query":"weather in Los Angeles"}', 'name': 'tavily_search_results_json'}, 'id': 'call_a5ZiWId9TSjjm5t3BDlNmGPA', 'type': 'function'}]}, response_metadata={'finish_reason': 'tool_calls', 'logprobs': None, 'model_name': 'gpt-3.5-turbo', 'system_fingerprint': None, 'token_usage': {'completion_tokens': 21, 'prompt_tokens': 152, 'total_tokens': 173}}, id='run-13f6de6b-b563-46b5-b140-b7513611a80a-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'current weather in Louisiana'}, 'id': 'call_a5ZiWId9TSjjm5t3BDlNmGPA'}])]}, next=('action',), config={'configurable': {'thread_id': '4', 'thread_ts': '1ef4b1b9-ca9e-6779-8002-aa29e8bfe228'}}, metadata={'source': 'update', 'step': 2, 'writes': {'llm': {'messages': [HumanMessage(content='Whats the weather in LA?', id='bf5d2a38-d276-4d0e-ac0f-a9e7ad4f75a4'), AIMessage(content='', additional_kwargs={'tool_calls': [{'function': {'arguments': '{"query":"weather in Los Angeles"}', 'name': 'tavily_search_results_json'}, 'id': 'call_a5ZiWId9TSjjm5t3BDlNmGPA', 'type': 'function'}]}, response_metadata={'finish_reason': 'tool_calls', 'logprobs': None, 'model_name': 'gpt-3.5-turbo', 'system_fingerprint': None, 'token_usage': {'completion_tokens': 21, 'prompt_tokens': 152, 'total_tokens': 173}}, id='run-13f6de6b-b563-46b5-b140-b7513611a80a-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'current weather in Louisiana'}, 'id': 'call_a5ZiWId9TSjjm5t3BDlNmGPA'}])]}}}, created_at='2024-07-26T06:52:23.635526+00:00', parent_config={'configurable': {'thread_id': '4', 'thread_ts': '1ef4b1b5-d983-62d3-8001-45142cf66e95'}})
# --
# StateSnapshot(values={'messages': [HumanMessage(content='Whats the weather in LA?', id='bf5d2a38-d276-4d0e-ac0f-a9e7ad4f75a4'), AIMessage(content='', additional_kwargs={'tool_calls': [{'function': {'arguments': '{"query":"weather in Los Angeles"}', 'name': 'tavily_search_results_json'}, 'id': 'call_a5ZiWId9TSjjm5t3BDlNmGPA', 'type': 'function'}]}, response_metadata={'finish_reason': 'tool_calls', 'logprobs': None, 'model_name': 'gpt-3.5-turbo', 'system_fingerprint': None, 'token_usage': {'completion_tokens': 21, 'prompt_tokens': 152, 'total_tokens': 173}}, id='run-13f6de6b-b563-46b5-b140-b7513611a80a-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'weather in Los Angeles'}, 'id': 'call_a5ZiWId9TSjjm5t3BDlNmGPA'}])]}, next=('action',), config={'configurable': {'thread_id': '4', 'thread_ts': '1ef4b1b5-d983-62d3-8001-45142cf66e95'}}, metadata={'source': 'loop', 'step': 1, 'writes': {'llm': {'messages': [AIMessage(content='', additional_kwargs={'tool_calls': [{'function': {'arguments': '{"query":"weather in Los Angeles"}', 'name': 'tavily_search_results_json'}, 'id': 'call_a5ZiWId9TSjjm5t3BDlNmGPA', 'type': 'function'}]}, response_metadata={'finish_reason': 'tool_calls', 'logprobs': None, 'model_name': 'gpt-3.5-turbo', 'system_fingerprint': None, 'token_usage': {'completion_tokens': 21, 'prompt_tokens': 152, 'total_tokens': 173}}, id='run-13f6de6b-b563-46b5-b140-b7513611a80a-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'weather in Los Angeles'}, 'id': 'call_a5ZiWId9TSjjm5t3BDlNmGPA'}])]}}}, created_at='2024-07-26T06:50:37.823030+00:00', parent_config={'configurable': {'thread_id': '4', 'thread_ts': '1ef4b1b5-d282-6568-8000-1f45df80a00f'}})
# --
# StateSnapshot(values={'messages': [HumanMessage(content='Whats the weather in LA?', id='bf5d2a38-d276-4d0e-ac0f-a9e7ad4f75a4')]}, next=('llm',), config={'configurable': {'thread_id': '4', 'thread_ts': '1ef4b1b5-d282-6568-8000-1f45df80a00f'}}, metadata={'source': 'loop', 'step': 0, 'writes': None}, created_at='2024-07-26T06:50:37.088683+00:00', parent_config={'configurable': {'thread_id': '4', 'thread_ts': '1ef4b1b5-d27f-681e-bfff-d2e05c982019'}})
# --
# StateSnapshot(values={'messages': []}, next=('__start__',), config={'configurable': {'thread_id': '4', 'thread_ts': '1ef4b1b5-d27f-681e-bfff-d2e05c982019'}}, metadata={'source': 'input', 'step': -1, 'writes': {'messages': [HumanMessage(content='Whats the weather in LA?')]}}, created_at='2024-07-26T06:50:37.087526+00:00', parent_config=None)
# --

# %% [markdown]
# To fetch the same state as was filmed, the offset below is changed to `-3` from `-1`. This accounts for the initial state `__start__` and the first state that are now stored to state memory with the latest version of software.

# %%
to_replay = states[-3]

# %%
to_replay
# Out:
# StateSnapshot(values={'messages': [HumanMessage(content='Whats the weather in LA?', id='bf5d2a38-d276-4d0e-ac0f-a9e7ad4f75a4'), AIMessage(content='', additional_kwargs={'tool_calls': [{'function': {'arguments': '{"query":"weather in Los Angeles"}', 'name': 'tavily_search_results_json'}, 'id': 'call_a5ZiWId9TSjjm5t3BDlNmGPA', 'type': 'function'}]}, response_metadata={'finish_reason': 'tool_calls', 'logprobs': None, 'model_name': 'gpt-3.5-turbo', 'system_fingerprint': None, 'token_usage': {'completion_tokens': 21, 'prompt_tokens': 152, 'total_tokens': 173}}, id='run-13f6de6b-b563-46b5-b140-b7513611a80a-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'weather in Los Angeles'}, 'id': 'call_a5ZiWId9TSjjm5t3BDlNmGPA'}])]}, next=('action',), config={'configurable': {'thread_id': '4', 'thread_ts': '1ef4b1b5-d983-62d3-8001-45142cf66e95'}}, metadata={'source': 'loop', 'step': 1, 'writes': {'llm': {'messages': [AIMessage(content='', additional_kwargs={'tool_calls': [{'function': {'arguments': '{"query":"weather in Los Angeles"}', 'name': 'tavily_search_results_json'}, 'id': 'call_a5ZiWId9TSjjm5t3BDlNmGPA', 'type': 'function'}]}, response_metadata={'finish_reason': 'tool_calls', 'logprobs': None, 'model_name': 'gpt-3.5-turbo', 'system_fingerprint': None, 'token_usage': {'completion_tokens': 21, 'prompt_tokens': 152, 'total_tokens': 173}}, id='run-13f6de6b-b563-46b5-b140-b7513611a80a-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'weather in Los Angeles'}, 'id': 'call_a5ZiWId9TSjjm5t3BDlNmGPA'}])]}}}, created_at='2024-07-26T06:50:37.823030+00:00', parent_config={'configurable': {'thread_id': '4', 'thread_ts': '1ef4b1b5-d282-6568-8000-1f45df80a00f'}})

# %%
for event in abot.graph.stream(None, to_replay.config):
    for k, v in event.items():
        print(v)
# Out:
# Calling: {'name': 'tavily_search_results_json', 'args': {'query': 'weather in Los Angeles'}, 'id': 'call_a5ZiWId9TSjjm5t3BDlNmGPA'}
# Back to the model!
# {'messages': [ToolMessage(content='[{\'url\': \'https://www.weatherapi.com/\', \'content\': "{\'location\': {\'name\': \'Los Angeles\', \'region\': \'California\', \'country\': \'United States of America\', \'lat\': 34.05, \'lon\': -118.24, \'tz_id\': \'America/Los_Angeles\', \'localtime_epoch\': 1721976868, \'localtime\': \'2024-07-25 23:54\'}, \'current\': {\'last_updated_epoch\': 1721976300, \'last_updated\': \'2024-07-25 23:45\', \'temp_c\': 25.3, \'temp_f\': 77.5, \'is_day\': 0, \'condition\': {\'text\': \'Clear\', \'icon\': \'//cdn.weatherapi.com/weather/64x64/night/113.png\', \'code\': 1000}, \'wind_mph\': 4.7, \'wind_kph\': 7.6, \'wind_degree\': 156, \'wind_dir\': \'SSE\', \'pressure_mb\': 1014.0, \'pressure_in\': 29.94, \'precip_mm\': 0.0, \'precip_in\': 0.0, \'humidity\': 52, \'cloud\': 3, \'feelslike_c\': 26.2, \'feelslike_f\': 79.1, \'windchill_c\': 25.3, \'windchill_f\': 77.5, \'heatindex_c\': 26.2, \'heatindex_f\': 79.1, \'dewpoint_c\': 14.8, \'dewpoint_f\': 58.6, \'vis_km\': 10.0, \'vis_miles\': 6.0, \'uv\': 1.0, \'gust_mph\': 6.3, \'gust_kph\': 10.1}}"}, {\'url\': \'https://www.meteoprog.com/weather/Losangeles/month/july/\', \'content\': \'Los Angeles (United States) weather in July 2024 ☀️ Accurate weather forecast for Los Angeles in July ⛅ Detailed forecast By month Current temperature "near me" Weather news ⊳ Widget of weather ⊳ Water temperature | METEOPROG. Meteoprog.com. ... 26 July +31 °+20° 27 July +31° ...\'}]', name='tavily_search_results_json', id='b578c9f4-36b2-42b4-bc4b-3afbd9843ecc', tool_call_id='call_a5ZiWId9TSjjm5t3BDlNmGPA')]}
# {'messages': [HumanMessage(content='Whats the weather in LA?', id='bf5d2a38-d276-4d0e-ac0f-a9e7ad4f75a4'), AIMessage(content='', additional_kwargs={'tool_calls': [{'function': {'arguments': '{"query":"weather in Los Angeles"}', 'name': 'tavily_search_results_json'}, 'id': 'call_a5ZiWId9TSjjm5t3BDlNmGPA', 'type': 'function'}]}, response_metadata={'finish_reason': 'tool_calls', 'logprobs': None, 'model_name': 'gpt-3.5-turbo', 'system_fingerprint': None, 'token_usage': {'completion_tokens': 21, 'prompt_tokens': 152, 'total_tokens': 173}}, id='run-13f6de6b-b563-46b5-b140-b7513611a80a-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'weather in Los Angeles'}, 'id': 'call_a5ZiWId9TSjjm5t3BDlNmGPA'}]), ToolMessage(content='[{\'url\': \'https://www.weatherapi.com/\', \'content\': "{\'location\': {\'name\': \'Los Angeles\', \'region\': \'California\', \'country\': \'United States of America\', \'lat\': 34.05, \'lon\': -118.24, \'tz_id\': \'America/Los_Angeles\', \'localtime_epoch\': 1721976868, \'localtime\': \'2024-07-25 23:54\'}, \'current\': {\'last_updated_epoch\': 1721976300, \'last_updated\': \'2024-07-25 23:45\', \'temp_c\': 25.3, \'temp_f\': 77.5, \'is_day\': 0, \'condition\': {\'text\': \'Clear\', \'icon\': \'//cdn.weatherapi.com/weather/64x64/night/113.png\', \'code\': 1000}, \'wind_mph\': 4.7, \'wind_kph\': 7.6, \'wind_degree\': 156, \'wind_dir\': \'SSE\', \'pressure_mb\': 1014.0, \'pressure_in\': 29.94, \'precip_mm\': 0.0, \'precip_in\': 0.0, \'humidity\': 52, \'cloud\': 3, \'feelslike_c\': 26.2, \'feelslike_f\': 79.1, \'windchill_c\': 25.3, \'windchill_f\': 77.5, \'heatindex_c\': 26.2, \'heatindex_f\': 79.1, \'dewpoint_c\': 14.8, \'dewpoint_f\': 58.6, \'vis_km\': 10.0, \'vis_miles\': 6.0, \'uv\': 1.0, \'gust_mph\': 6.3, \'gust_kph\': 10.1}}"}, {\'url\': \'https://www.meteoprog.com/weather/Losangeles/month/july/\', \'content\': \'Los Angeles (United States) weather in July 2024 ☀️ Accurate weather forecast for Los Angeles in July ⛅ Detailed forecast By month Current temperature "near me" Weather news ⊳ Widget of weather ⊳ Water temperature | METEOPROG. Meteoprog.com. ... 26 July +31 °+20° 27 July +31° ...\'}]', name='tavily_search_results_json', id='b578c9f4-36b2-42b4-bc4b-3afbd9843ecc', tool_call_id='call_a5ZiWId9TSjjm5t3BDlNmGPA'), AIMessage(content='The current weather in Los Angeles is clear with a temperature of 77.5°F (25.3°C). The wind is blowing at 7.6 km/h from the SSE direction. The humidity is at 52%, and the visibility is 6.0 miles.', response_metadata={'token_usage': {'completion_tokens': 57, 'prompt_tokens': 698, 'total_tokens': 755}, 'model_name': 'gpt-3.5-turbo', 'system_fingerprint': None, 'finish_reason': 'stop', 'logprobs': None}, id='run-1f36e145-cfd6-4f23-b8a8-c78ed55d1b03-0')]}
# {'messages': [AIMessage(content='The current weather in Los Angeles is clear with a temperature of 77.5°F (25.3°C). The wind is blowing at 7.6 km/h from the SSE direction. The humidity is at 52%, and the visibility is 6.0 miles.', response_metadata={'token_usage': {'completion_tokens': 57, 'prompt_tokens': 698, 'total_tokens': 755}, 'model_name': 'gpt-3.5-turbo', 'system_fingerprint': None, 'finish_reason': 'stop', 'logprobs': None}, id='run-1f36e145-cfd6-4f23-b8a8-c78ed55d1b03-0')]}

# %% [markdown]
# ## Go back in time and edit

# %%
to_replay
# Out:
# StateSnapshot(values={'messages': [HumanMessage(content='Whats the weather in LA?', id='bf5d2a38-d276-4d0e-ac0f-a9e7ad4f75a4'), AIMessage(content='', additional_kwargs={'tool_calls': [{'function': {'arguments': '{"query":"weather in Los Angeles"}', 'name': 'tavily_search_results_json'}, 'id': 'call_a5ZiWId9TSjjm5t3BDlNmGPA', 'type': 'function'}]}, response_metadata={'finish_reason': 'tool_calls', 'logprobs': None, 'model_name': 'gpt-3.5-turbo', 'system_fingerprint': None, 'token_usage': {'completion_tokens': 21, 'prompt_tokens': 152, 'total_tokens': 173}}, id='run-13f6de6b-b563-46b5-b140-b7513611a80a-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'weather in Los Angeles'}, 'id': 'call_a5ZiWId9TSjjm5t3BDlNmGPA'}])]}, next=('action',), config={'configurable': {'thread_id': '4', 'thread_ts': '1ef4b1b5-d983-62d3-8001-45142cf66e95'}}, metadata={'source': 'loop', 'step': 1, 'writes': {'llm': {'messages': [AIMessage(content='', additional_kwargs={'tool_calls': [{'function': {'arguments': '{"query":"weather in Los Angeles"}', 'name': 'tavily_search_results_json'}, 'id': 'call_a5ZiWId9TSjjm5t3BDlNmGPA', 'type': 'function'}]}, response_metadata={'finish_reason': 'tool_calls', 'logprobs': None, 'model_name': 'gpt-3.5-turbo', 'system_fingerprint': None, 'token_usage': {'completion_tokens': 21, 'prompt_tokens': 152, 'total_tokens': 173}}, id='run-13f6de6b-b563-46b5-b140-b7513611a80a-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'weather in Los Angeles'}, 'id': 'call_a5ZiWId9TSjjm5t3BDlNmGPA'}])]}}}, created_at='2024-07-26T06:50:37.823030+00:00', parent_config={'configurable': {'thread_id': '4', 'thread_ts': '1ef4b1b5-d282-6568-8000-1f45df80a00f'}})

# %%
_id = to_replay.values['messages'][-1].tool_calls[0]['id']
to_replay.values['messages'][-1].tool_calls = [{'name': 'tavily_search_results_json',
  'args': {'query': 'current weather in LA, accuweather'},
  'id': _id}]

# %%
branch_state = abot.graph.update_state(to_replay.config, to_replay.values)
# Out:
# {'messages': [HumanMessage(content='Whats the weather in LA?', id='bf5d2a38-d276-4d0e-ac0f-a9e7ad4f75a4'), AIMessage(content='', additional_kwargs={'tool_calls': [{'function': {'arguments': '{"query":"weather in Los Angeles"}', 'name': 'tavily_search_results_json'}, 'id': 'call_a5ZiWId9TSjjm5t3BDlNmGPA', 'type': 'function'}]}, response_metadata={'finish_reason': 'tool_calls', 'logprobs': None, 'model_name': 'gpt-3.5-turbo', 'system_fingerprint': None, 'token_usage': {'completion_tokens': 21, 'prompt_tokens': 152, 'total_tokens': 173}}, id='run-13f6de6b-b563-46b5-b140-b7513611a80a-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'current weather in LA, accuweather'}, 'id': 'call_a5ZiWId9TSjjm5t3BDlNmGPA'}])]}

# %%
for event in abot.graph.stream(None, branch_state):
    for k, v in event.items():
        if k != "__end__":
            print(v)
# Out:
# Calling: {'name': 'tavily_search_results_json', 'args': {'query': 'current weather in LA, accuweather'}, 'id': 'call_a5ZiWId9TSjjm5t3BDlNmGPA'}
# Back to the model!
# {'messages': [ToolMessage(content='[{\'url\': \'https://www.weatherapi.com/\', \'content\': "{\'location\': {\'name\': \'Los Angeles\', \'region\': \'California\', \'country\': \'United States of America\', \'lat\': 34.05, \'lon\': -118.24, \'tz_id\': \'America/Los_Angeles\', \'localtime_epoch\': 1721976868, \'localtime\': \'2024-07-25 23:54\'}, \'current\': {\'last_updated_epoch\': 1721976300, \'last_updated\': \'2024-07-25 23:45\', \'temp_c\': 25.3, \'temp_f\': 77.5, \'is_day\': 0, \'condition\': {\'text\': \'Clear\', \'icon\': \'//cdn.weatherapi.com/weather/64x64/night/113.png\', \'code\': 1000}, \'wind_mph\': 4.7, \'wind_kph\': 7.6, \'wind_degree\': 156, \'wind_dir\': \'SSE\', \'pressure_mb\': 1014.0, \'pressure_in\': 29.94, \'precip_mm\': 0.0, \'precip_in\': 0.0, \'humidity\': 52, \'cloud\': 3, \'feelslike_c\': 26.2, \'feelslike_f\': 79.1, \'windchill_c\': 25.3, \'windchill_f\': 77.5, \'heatindex_c\': 26.2, \'heatindex_f\': 79.1, \'dewpoint_c\': 14.8, \'dewpoint_f\': 58.6, \'vis_km\': 10.0, \'vis_miles\': 6.0, \'uv\': 1.0, \'gust_mph\': 6.3, \'gust_kph\': 10.1}}"}, {\'url\': \'https://www.accuweather.com/en/us/los-angeles/90012/weather-forecast/347625\', \'content\': \'Get the latest weather forecast for Los Angeles, CA, with AccuWeather. Find out the temperature, air quality, wind, rain, and UV index for today and the next three days.\'}]', name='tavily_search_results_json', id='094adbce-3e0e-4959-b9eb-c61c81687dde', tool_call_id='call_a5ZiWId9TSjjm5t3BDlNmGPA')]}
# {'messages': [HumanMessage(content='Whats the weather in LA?', id='bf5d2a38-d276-4d0e-ac0f-a9e7ad4f75a4'), AIMessage(content='', additional_kwargs={'tool_calls': [{'function': {'arguments': '{"query":"weather in Los Angeles"}', 'name': 'tavily_search_results_json'}, 'id': 'call_a5ZiWId9TSjjm5t3BDlNmGPA', 'type': 'function'}]}, response_metadata={'finish_reason': 'tool_calls', 'logprobs': None, 'model_name': 'gpt-3.5-turbo', 'system_fingerprint': None, 'token_usage': {'completion_tokens': 21, 'prompt_tokens': 152, 'total_tokens': 173}}, id='run-13f6de6b-b563-46b5-b140-b7513611a80a-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'current weather in LA, accuweather'}, 'id': 'call_a5ZiWId9TSjjm5t3BDlNmGPA'}]), ToolMessage(content='[{\'url\': \'https://www.weatherapi.com/\', \'content\': "{\'location\': {\'name\': \'Los Angeles\', \'region\': \'California\', \'country\': \'United States of America\', \'lat\': 34.05, \'lon\': -118.24, \'tz_id\': \'America/Los_Angeles\', \'localtime_epoch\': 1721976868, \'localtime\': \'2024-07-25 23:54\'}, \'current\': {\'last_updated_epoch\': 1721976300, \'last_updated\': \'2024-07-25 23:45\', \'temp_c\': 25.3, \'temp_f\': 77.5, \'is_day\': 0, \'condition\': {\'text\': \'Clear\', \'icon\': \'//cdn.weatherapi.com/weather/64x64/night/113.png\', \'code\': 1000}, \'wind_mph\': 4.7, \'wind_kph\': 7.6, \'wind_degree\': 156, \'wind_dir\': \'SSE\', \'pressure_mb\': 1014.0, \'pressure_in\': 29.94, \'precip_mm\': 0.0, \'precip_in\': 0.0, \'humidity\': 52, \'cloud\': 3, \'feelslike_c\': 26.2, \'feelslike_f\': 79.1, \'windchill_c\': 25.3, \'windchill_f\': 77.5, \'heatindex_c\': 26.2, \'heatindex_f\': 79.1, \'dewpoint_c\': 14.8, \'dewpoint_f\': 58.6, \'vis_km\': 10.0, \'vis_miles\': 6.0, \'uv\': 1.0, \'gust_mph\': 6.3, \'gust_kph\': 10.1}}"}, {\'url\': \'https://www.accuweather.com/en/us/los-angeles/90012/weather-forecast/347625\', \'content\': \'Get the latest weather forecast for Los Angeles, CA, with AccuWeather. Find out the temperature, air quality, wind, rain, and UV index for today and the next three days.\'}]', name='tavily_search_results_json', id='094adbce-3e0e-4959-b9eb-c61c81687dde', tool_call_id='call_a5ZiWId9TSjjm5t3BDlNmGPA'), AIMessage(content='The current weather in Los Angeles is as follows:\n- Temperature: 77.5°F (25.3°C)\n- Condition: Clear\n- Wind: 4.7 mph from SSE\n- Pressure: 29.94 in\n- Humidity: 52%\n- Visibility: 6.0 miles\n\nFor more detailed weather forecast information, you can visit [AccuWeather](https://www.accuweather.com/en/us/los-angeles/90012/weather-forecast/347625).', response_metadata={'token_usage': {'completion_tokens': 105, 'prompt_tokens': 669, 'total_tokens': 774}, 'model_name': 'gpt-3.5-turbo', 'system_fingerprint': None, 'finish_reason': 'stop', 'logprobs': None}, id='run-71722931-b4bd-44e4-b263-94d5860ea251-0')]}
# {'messages': [AIMessage(content='The current weather in Los Angeles is as follows:\n- Temperature: 77.5°F (25.3°C)\n- Condition: Clear\n- Wind: 4.7 mph from SSE\n- Pressure: 29.94 in\n- Humidity: 52%\n- Visibility: 6.0 miles\n\nFor more detailed weather forecast information, you can visit [AccuWeather](https://www.accuweather.com/en/us/los-angeles/90012/weather-forecast/347625).', response_metadata={'token_usage': {'completion_tokens': 105, 'prompt_tokens': 669, 'total_tokens': 774}, 'model_name': 'gpt-3.5-turbo', 'system_fingerprint': None, 'finish_reason': 'stop', 'logprobs': None}, id='run-71722931-b4bd-44e4-b263-94d5860ea251-0')]}

# %% [markdown]
# ## Add message to a state at a given time

# %%
to_replay
# Out:
# StateSnapshot(values={'messages': [HumanMessage(content='Whats the weather in LA?', id='bf5d2a38-d276-4d0e-ac0f-a9e7ad4f75a4'), AIMessage(content='', additional_kwargs={'tool_calls': [{'function': {'arguments': '{"query":"weather in Los Angeles"}', 'name': 'tavily_search_results_json'}, 'id': 'call_a5ZiWId9TSjjm5t3BDlNmGPA', 'type': 'function'}]}, response_metadata={'finish_reason': 'tool_calls', 'logprobs': None, 'model_name': 'gpt-3.5-turbo', 'system_fingerprint': None, 'token_usage': {'completion_tokens': 21, 'prompt_tokens': 152, 'total_tokens': 173}}, id='run-13f6de6b-b563-46b5-b140-b7513611a80a-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'current weather in LA, accuweather'}, 'id': 'call_a5ZiWId9TSjjm5t3BDlNmGPA'}])]}, next=('action',), config={'configurable': {'thread_id': '4', 'thread_ts': '1ef4b1b5-d983-62d3-8001-45142cf66e95'}}, metadata={'source': 'loop', 'step': 1, 'writes': {'llm': {'messages': [AIMessage(content='', additional_kwargs={'tool_calls': [{'function': {'arguments': '{"query":"weather in Los Angeles"}', 'name': 'tavily_search_results_json'}, 'id': 'call_a5ZiWId9TSjjm5t3BDlNmGPA', 'type': 'function'}]}, response_metadata={'finish_reason': 'tool_calls', 'logprobs': None, 'model_name': 'gpt-3.5-turbo', 'system_fingerprint': None, 'token_usage': {'completion_tokens': 21, 'prompt_tokens': 152, 'total_tokens': 173}}, id='run-13f6de6b-b563-46b5-b140-b7513611a80a-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'weather in Los Angeles'}, 'id': 'call_a5ZiWId9TSjjm5t3BDlNmGPA'}])]}}}, created_at='2024-07-26T06:50:37.823030+00:00', parent_config={'configurable': {'thread_id': '4', 'thread_ts': '1ef4b1b5-d282-6568-8000-1f45df80a00f'}})

# %%
_id = to_replay.values['messages'][-1].tool_calls[0]['id']

# %%
state_update = {"messages": [ToolMessage(
    tool_call_id=_id,
    name="tavily_search_results_json",
    content="54 degree celcius",
)]}

# %%
branch_and_add = abot.graph.update_state(
    to_replay.config, 
    state_update, 
    as_node="action") ### The state update that we are making isnt just a modification . We are actually making this update as if we were the action node

## Before we add this message,The current state of graph is about to go into the action node .
## But after we add this message , We dont want to go into action node anymore.

## Basically we are saying that , We are acting as if we are the action node

# %%
for event in abot.graph.stream(None, branch_and_add):
    for k, v in event.items():
        print(v)
# Out:
# {'messages': [HumanMessage(content='Whats the weather in LA?', id='bf5d2a38-d276-4d0e-ac0f-a9e7ad4f75a4'), AIMessage(content='', additional_kwargs={'tool_calls': [{'function': {'arguments': '{"query":"weather in Los Angeles"}', 'name': 'tavily_search_results_json'}, 'id': 'call_a5ZiWId9TSjjm5t3BDlNmGPA', 'type': 'function'}]}, response_metadata={'finish_reason': 'tool_calls', 'logprobs': None, 'model_name': 'gpt-3.5-turbo', 'system_fingerprint': None, 'token_usage': {'completion_tokens': 21, 'prompt_tokens': 152, 'total_tokens': 173}}, id='run-13f6de6b-b563-46b5-b140-b7513611a80a-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'weather in Los Angeles'}, 'id': 'call_a5ZiWId9TSjjm5t3BDlNmGPA'}]), ToolMessage(content='54 degree celcius', name='tavily_search_results_json', id='7cd37b13-3e2b-471b-9be9-574e3a333f44', tool_call_id='call_a5ZiWId9TSjjm5t3BDlNmGPA'), AIMessage(content='The current weather in Los Angeles is 54 degrees Celsius.', response_metadata={'token_usage': {'completion_tokens': 13, 'prompt_tokens': 190, 'total_tokens': 203}, 'model_name': 'gpt-3.5-turbo', 'system_fingerprint': None, 'finish_reason': 'stop', 'logprobs': None}, id='run-7d9643a1-32f7-439c-80ed-2da60cdc9789-0')]}
# {'messages': [AIMessage(content='The current weather in Los Angeles is 54 degrees Celsius.', response_metadata={'token_usage': {'completion_tokens': 13, 'prompt_tokens': 190, 'total_tokens': 203}, 'model_name': 'gpt-3.5-turbo', 'system_fingerprint': None, 'finish_reason': 'stop', 'logprobs': None}, id='run-7d9643a1-32f7-439c-80ed-2da60cdc9789-0')]}

# %% [markdown]
# # Extra Practice

# %% [markdown]
# ## Build a small graph
# This is a small simple graph you can tinker with if you want more insight into controlling state memory.

# %%
from dotenv import load_dotenv

_ = load_dotenv()

# %%
from langgraph.graph import StateGraph, END
from typing import TypedDict, Annotated
import operator
from langgraph.checkpoint.sqlite import SqliteSaver

# %% [markdown]
# Define a simple 2 node graph with the following state:
# -`lnode`: last node
# -`scratch`: a scratchpad location
# -`count` : a counter that is incremented each step

# %%
class AgentState(TypedDict):
    lnode: str
    scratch: str
    count: Annotated[int, operator.add]

# %%
def node1(state: AgentState):
    print(f"node1, count:{state['count']}")
    return {"lnode": "node_1",
            "count": 1,
           }
def node2(state: AgentState):
    print(f"node2, count:{state['count']}")
    return {"lnode": "node_2",
            "count": 1,
           }

# %% [markdown]
# The graph goes N1->N2->N1... but breaks after count reaches 3.

# %%
def should_continue(state):
    return state["count"] < 3

# %%
builder = StateGraph(AgentState)
builder.add_node("Node1", node1)
builder.add_node("Node2", node2)

builder.add_edge("Node1", "Node2")
builder.add_conditional_edges("Node2", 
                              should_continue, 
                              {True: "Node1", False: END})
builder.set_entry_point("Node1")

# %%
memory = SqliteSaver.from_conn_string(":memory:")
graph = builder.compile(checkpointer=memory)

# %% [markdown]
# ### Run it!
# Now, set the thread and run!

# %%
thread = {"configurable": {"thread_id": str(1)}}
graph.invoke({"count":0, "scratch":"hi"},thread)
# Out:
# node1, count:0
# node2, count:1
# node1, count:2
# node2, count:3
# {'lnode': 'node_2', 'scratch': 'hi', 'count': 4}

# %% [markdown]
# ### Look at current state

# %% [markdown]
# Get the current state. Note the `values` which are the AgentState. Note the `config` and the `thread_ts`. You will be using those to refer to snapshots below.

# %%
graph.get_state(thread)
# Out:
# StateSnapshot(values={'lnode': 'node_2', 'scratch': 'hi', 'count': 4}, next=(), config={'configurable': {'thread_id': '1', 'thread_ts': '1ef4b1d2-8ac8-6eb0-8004-cc798804f7fc'}}, metadata={'source': 'loop', 'step': 4, 'writes': {'Node2': {'count': 1, 'lnode': 'node_2'}}}, created_at='2024-07-26T07:03:28.030674+00:00', parent_config={'configurable': {'thread_id': '1', 'thread_ts': '1ef4b1d2-8ac6-60c7-8003-ccee2a374e45'}})

# %% [markdown]
# View all the statesnapshots in memory. You can use the displayed `count` agentstate variable to help track what you see. Notice the most recent snapshots are returned by the iterator first. Also note that there is a handy `step` variable in the metadata that counts the number of steps in the graph execution. This is a bit detailed - but you can also notice that the *parent_config* is the *config* of the previous node. At initial startup, additional states are inserted into memory to create a parent. This is something to check when you branch or *time travel* below.

# %% [markdown]
# ### Look at state history

# %%
for state in graph.get_state_history(thread):
    print(state, "\n")
# Out:
# StateSnapshot(values={'lnode': 'node_2', 'scratch': 'hi', 'count': 4}, next=(), config={'configurable': {'thread_id': '1', 'thread_ts': '1ef4b1d2-8ac8-6eb0-8004-cc798804f7fc'}}, metadata={'source': 'loop', 'step': 4, 'writes': {'Node2': {'count': 1, 'lnode': 'node_2'}}}, created_at='2024-07-26T07:03:28.030674+00:00', parent_config={'configurable': {'thread_id': '1', 'thread_ts': '1ef4b1d2-8ac6-60c7-8003-ccee2a374e45'}})
#
# StateSnapshot(values={'lnode': 'node_1', 'scratch': 'hi', 'count': 3}, next=('Node2',), config={'configurable': {'thread_id': '1', 'thread_ts': '1ef4b1d2-8ac6-60c7-8003-ccee2a374e45'}}, metadata={'source': 'loop', 'step': 3, 'writes': {'Node1': {'count': 1, 'lnode': 'node_1'}}}, created_at='2024-07-26T07:03:28.029498+00:00', parent_config={'configurable': {'thread_id': '1', 'thread_ts': '1ef4b1d2-8ac3-6859-8002-60ea3d69fa7e'}})
#
# StateSnapshot(values={'lnode': 'node_2', 'scratch': 'hi', 'count': 2}, next=('Node1',), config={'configurable': {'thread_id': '1', 'thread_ts': '1ef4b1d2-8ac3-6859-8002-60ea3d69fa7e'}}, metadata={'source': 'loop', 'step': 2, 'writes': {'Node2': {'count': 1, 'lnode': 'node_2'}}}, created_at='2024-07-26T07:03:28.028463+00:00', parent_config={'configurable': {'thread_id': '1', 'thread_ts': '1ef4b1d2-8abe-6894-8001-11bc8392ea4a'}})
#
# StateSnapshot(values={'lnode': 'node_1', 'scratch': 'hi', 'count': 1}, next=('Node2',), config={'configurable': {'thread_id': '1', 'thread_ts': '1ef4b1d2-8abe-6894-8001-11bc8392ea4a'}}, metadata={'source': 'loop', 'step': 1, 'writes': {'Node1': {'count': 1, 'lnode': 'node_1'}}}, created_at='2024-07-26T07:03:28.026420+00:00', parent_config={'configurable': {'thread_id': '1', 'thread_ts': '1ef4b1d2-8aba-66ca-8000-0219be05dfed'}})
#
# StateSnapshot(values={'scratch': 'hi', 'count': 0}, next=('Node1',), config={'configurable': {'thread_id': '1', 'thread_ts': '1ef4b1d2-8aba-66ca-8000-0219be05dfed'}}, metadata={'source': 'loop', 'step': 0, 'writes': None}, created_at='2024-07-26T07:03:28.024735+00:00', parent_config={'configurable': {'thread_id': '1', 'thread_ts': '1ef4b1d2-8ab7-6569-bfff-d34dbb545032'}})
#
# StateSnapshot(values={'count': 0}, next=('__start__',), config={'configurable': {'thread_id': '1', 'thread_ts': '1ef4b1d2-8ab7-6569-bfff-d34dbb545032'}}, metadata={'source': 'input', 'step': -1, 'writes': {'count': 0, 'scratch': 'hi'}}, created_at='2024-07-26T07:03:28.023472+00:00', parent_config=None)

# %% [markdown]
# Store just the `config` into an list. Note the sequence of counts on the right. `get_state_history` returns the most recent snapshots first.

# %%
states = []
for state in graph.get_state_history(thread):
    states.append(state.config)
    print(state.config, state.values['count'])
# Out:
# {'configurable': {'thread_id': '1', 'thread_ts': '1ef4b1d2-8ac8-6eb0-8004-cc798804f7fc'}} 4
# {'configurable': {'thread_id': '1', 'thread_ts': '1ef4b1d2-8ac6-60c7-8003-ccee2a374e45'}} 3
# {'configurable': {'thread_id': '1', 'thread_ts': '1ef4b1d2-8ac3-6859-8002-60ea3d69fa7e'}} 2
# {'configurable': {'thread_id': '1', 'thread_ts': '1ef4b1d2-8abe-6894-8001-11bc8392ea4a'}} 1
# {'configurable': {'thread_id': '1', 'thread_ts': '1ef4b1d2-8aba-66ca-8000-0219be05dfed'}} 0
# {'configurable': {'thread_id': '1', 'thread_ts': '1ef4b1d2-8ab7-6569-bfff-d34dbb545032'}} 0

# %% [markdown]
# Grab an early state.

# %%
states[-3]
# Out:
# {'configurable': {'thread_id': '1',
#   'thread_ts': '1ef4b1d2-8abe-6894-8001-11bc8392ea4a'}}

# %% [markdown]
# This is the state after Node1 completed for the first time. Note `next` is `Node2`and `count` is 1.

# %%
graph.get_state(states[-3])
# Out:
# StateSnapshot(values={'lnode': 'node_1', 'scratch': 'hi', 'count': 1}, next=('Node2',), config={'configurable': {'thread_id': '1', 'thread_ts': '1ef4b1d2-8abe-6894-8001-11bc8392ea4a'}}, metadata={'source': 'loop', 'step': 1, 'writes': {'Node1': {'count': 1, 'lnode': 'node_1'}}}, created_at='2024-07-26T07:03:28.026420+00:00', parent_config={'configurable': {'thread_id': '1', 'thread_ts': '1ef4b1d2-8aba-66ca-8000-0219be05dfed'}})

# %% [markdown]
# ### Go Back in Time
# Use that state in `invoke` to go back in time. Notice it uses states[-3] as *current_state* and continues to node2,

# %%
graph.invoke(None, states[-3])
# Out:
# node2, count:1
# node1, count:2
# node2, count:3
# {'lnode': 'node_2', 'scratch': 'hi', 'count': 4}

# %% [markdown]
# Notice the new states are now in state history. Notice the counts on the far right.

# %%
thread = {"configurable": {"thread_id": str(1)}}
for state in graph.get_state_history(thread):
    print(state.config, state.values['count'])
# Out:
# {'configurable': {'thread_id': '1', 'thread_ts': '1ef4b1d3-4c26-647d-8004-13598e422bc3'}} 4
# {'configurable': {'thread_id': '1', 'thread_ts': '1ef4b1d3-4c23-6012-8003-257293dae2f8'}} 3
# {'configurable': {'thread_id': '1', 'thread_ts': '1ef4b1d3-4c20-696b-8002-481718f4c459'}} 2
# {'configurable': {'thread_id': '1', 'thread_ts': '1ef4b1d2-8ac8-6eb0-8004-cc798804f7fc'}} 4
# {'configurable': {'thread_id': '1', 'thread_ts': '1ef4b1d2-8ac6-60c7-8003-ccee2a374e45'}} 3
# {'configurable': {'thread_id': '1', 'thread_ts': '1ef4b1d2-8ac3-6859-8002-60ea3d69fa7e'}} 2
# {'configurable': {'thread_id': '1', 'thread_ts': '1ef4b1d2-8abe-6894-8001-11bc8392ea4a'}} 1
# {'configurable': {'thread_id': '1', 'thread_ts': '1ef4b1d2-8aba-66ca-8000-0219be05dfed'}} 0
# {'configurable': {'thread_id': '1', 'thread_ts': '1ef4b1d2-8ab7-6569-bfff-d34dbb545032'}} 0

# %% [markdown]
# You can see the details below. Lots of text, but try to find the node that start the new branch. Notice the parent *config* is not the previous entry in the stack, but is the entry from state[-3].

# %%
thread = {"configurable": {"thread_id": str(1)}}
for state in graph.get_state_history(thread):
    print(state,"\n")
# Out:
# StateSnapshot(values={'lnode': 'node_2', 'scratch': 'hi', 'count': 4}, next=(), config={'configurable': {'thread_id': '1', 'thread_ts': '1ef4b1d3-4c26-647d-8004-13598e422bc3'}}, metadata={'source': 'loop', 'step': 4, 'writes': {'Node2': {'count': 1, 'lnode': 'node_2'}}}, created_at='2024-07-26T07:03:48.306431+00:00', parent_config={'configurable': {'thread_id': '1', 'thread_ts': '1ef4b1d3-4c23-6012-8003-257293dae2f8'}})
#
# StateSnapshot(values={'lnode': 'node_1', 'scratch': 'hi', 'count': 3}, next=('Node2',), config={'configurable': {'thread_id': '1', 'thread_ts': '1ef4b1d3-4c23-6012-8003-257293dae2f8'}}, metadata={'source': 'loop', 'step': 3, 'writes': {'Node1': {'count': 1, 'lnode': 'node_1'}}}, created_at='2024-07-26T07:03:48.305089+00:00', parent_config={'configurable': {'thread_id': '1', 'thread_ts': '1ef4b1d3-4c20-696b-8002-481718f4c459'}})
#
# StateSnapshot(values={'lnode': 'node_2', 'scratch': 'hi', 'count': 2}, next=('Node1',), config={'configurable': {'thread_id': '1', 'thread_ts': '1ef4b1d3-4c20-696b-8002-481718f4c459'}}, metadata={'source': 'loop', 'step': 2, 'writes': {'Node2': {'count': 1, 'lnode': 'node_2'}}}, created_at='2024-07-26T07:03:48.304098+00:00', parent_config={'configurable': {'thread_id': '1', 'thread_ts': '1ef4b1d2-8abe-6894-8001-11bc8392ea4a'}})
#
# StateSnapshot(values={'lnode': 'node_2', 'scratch': 'hi', 'count': 4}, next=(), config={'configurable': {'thread_id': '1', 'thread_ts': '1ef4b1d2-8ac8-6eb0-8004-cc798804f7fc'}}, metadata={'source': 'loop', 'step': 4, 'writes': {'Node2': {'count': 1, 'lnode': 'node_2'}}}, created_at='2024-07-26T07:03:28.030674+00:00', parent_config={'configurable': {'thread_id': '1', 'thread_ts': '1ef4b1d2-8ac6-60c7-8003-ccee2a374e45'}})
#
# StateSnapshot(values={'lnode': 'node_1', 'scratch': 'hi', 'count': 3}, next=('Node2',), config={'configurable': {'thread_id': '1', 'thread_ts': '1ef4b1d2-8ac6-60c7-8003-ccee2a374e45'}}, metadata={'source': 'loop', 'step': 3, 'writes': {'Node1': {'count': 1, 'lnode': 'node_1'}}}, created_at='2024-07-26T07:03:28.029498+00:00', parent_config={'configurable': {'thread_id': '1', 'thread_ts': '1ef4b1d2-8ac3-6859-8002-60ea3d69fa7e'}})
#
# StateSnapshot(values={'lnode': 'node_2', 'scratch': 'hi', 'count': 2}, next=('Node1',), config={'configurable': {'thread_id': '1', 'thread_ts': '1ef4b1d2-8ac3-6859-8002-60ea3d69fa7e'}}, metadata={'source': 'loop', 'step': 2, 'writes': {'Node2': {'count': 1, 'lnode': 'node_2'}}}, created_at='2024-07-26T07:03:28.028463+00:00', parent_config={'configurable': {'thread_id': '1', 'thread_ts': '1ef4b1d2-8abe-6894-8001-11bc8392ea4a'}})
#
# StateSnapshot(values={'lnode': 'node_1', 'scratch': 'hi', 'count': 1}, next=('Node2',), config={'configurable': {'thread_id': '1', 'thread_ts': '1ef4b1d2-8abe-6894-8001-11bc8392ea4a'}}, metadata={'source': 'loop', 'step': 1, 'writes': {'Node1': {'count': 1, 'lnode': 'node_1'}}}, created_at='2024-07-26T07:03:28.026420+00:00', parent_config={'configurable': {'thread_id': '1', 'thread_ts': '1ef4b1d2-8aba-66ca-8000-0219be05dfed'}})
#
# StateSnapshot(values={'scratch': 'hi', 'count': 0}, next=('Node1',), config={'configurable': {'thread_id': '1', 'thread_ts': '1ef4b1d2-8aba-66ca-8000-0219be05dfed'}}, metadata={'source': 'loop', 'step': 0, 'writes': None}, created_at='2024-07-26T07:03:28.024735+00:00', parent_config={'configurable': {'thread_id': '1', 'thread_ts': '1ef4b1d2-8ab7-6569-bfff-d34dbb545032'}})
#
# StateSnapshot(values={'count': 0}, next=('__start__',), config={'configurable': {'thread_id': '1', 'thread_ts': '1ef4b1d2-8ab7-6569-bfff-d34dbb545032'}}, metadata={'source': 'input', 'step': -1, 'writes': {'count': 0, 'scratch': 'hi'}}, created_at='2024-07-26T07:03:28.023472+00:00', parent_config=None)

# %% [markdown]
# ### Modify State
# Let's start by starting a fresh thread and running to clean out history.

# %%
thread2 = {"configurable": {"thread_id": str(2)}}
graph.invoke({"count":0, "scratch":"hi"},thread2)
# Out:
# node1, count:0
# node2, count:1
# node1, count:2
# node2, count:3
# {'lnode': 'node_2', 'scratch': 'hi', 'count': 4}

# %%
from IPython.display import Image

Image(graph.get_graph().draw_png())

# %%
states2 = []
for state in graph.get_state_history(thread2):
    states2.append(state.config)
    print(state.config, state.values['count'])
# Out:
# {'configurable': {'thread_id': '2', 'thread_ts': '1ef4b1d3-deb4-68a8-8004-39827de2318f'}} 4
# {'configurable': {'thread_id': '2', 'thread_ts': '1ef4b1d3-deb1-6489-8003-3f8a828662e8'}} 3
# {'configurable': {'thread_id': '2', 'thread_ts': '1ef4b1d3-deae-6ff6-8002-8faf28afed99'}} 2
# {'configurable': {'thread_id': '2', 'thread_ts': '1ef4b1d3-deaa-6e24-8001-097ff1665a4e'}} 1
# {'configurable': {'thread_id': '2', 'thread_ts': '1ef4b1d3-dea7-6889-8000-8b4a919cd608'}} 0
# {'configurable': {'thread_id': '2', 'thread_ts': '1ef4b1d3-dea4-6c90-bfff-127bcaf34070'}} 0

# %% [markdown]
# Start by grabbing a state.

# %%
save_state = graph.get_state(states2[-3])
save_state
# Out:
# StateSnapshot(values={'lnode': 'node_1', 'scratch': 'hi', 'count': 1}, next=('Node2',), config={'configurable': {'thread_id': '2', 'thread_ts': '1ef4b1d3-deaa-6e24-8001-097ff1665a4e'}}, metadata={'source': 'loop', 'step': 1, 'writes': {'Node1': {'count': 1, 'lnode': 'node_1'}}}, created_at='2024-07-26T07:04:03.669954+00:00', parent_config={'configurable': {'thread_id': '2', 'thread_ts': '1ef4b1d3-dea7-6889-8000-8b4a919cd608'}})

# %% [markdown]
# Now modify the values. One subtle item to note: Recall when agent state was defined, `count` used `operator.add` to indicate that values are *added* to the current value. Here, `-3` will be added to the current count value rather than replace it.

# %%
save_state.values["count"] = -3
save_state.values["scratch"] = "hello"
save_state
# Out:
# StateSnapshot(values={'lnode': 'node_1', 'scratch': 'hello', 'count': -3}, next=('Node2',), config={'configurable': {'thread_id': '2', 'thread_ts': '1ef4b1d3-deaa-6e24-8001-097ff1665a4e'}}, metadata={'source': 'loop', 'step': 1, 'writes': {'Node1': {'count': 1, 'lnode': 'node_1'}}}, created_at='2024-07-26T07:04:03.669954+00:00', parent_config={'configurable': {'thread_id': '2', 'thread_ts': '1ef4b1d3-dea7-6889-8000-8b4a919cd608'}})

# %% [markdown]
# Now update the state. This creates a new entry at the *top*, or *latest* entry in memory. This will become the current state.

# %%
graph.update_state(thread2,save_state.values)
# Out:
# {'configurable': {'thread_id': '2',
#   'thread_ts': '1ef4b1d4-6311-60ae-8005-c81b709f4fb2'}}

# %% [markdown]
# Current state is at the top. You can match the `thread_ts`.
# Notice the `parent_config`, `thread_ts` of the new node - it is the previous node.

# %%
for i, state in enumerate(graph.get_state_history(thread2)):
    if i >= 3:  #print latest 3
        break
    print(state, '\n')
# Out:
# StateSnapshot(values={'lnode': 'node_1', 'scratch': 'hello', 'count': 1}, next=('Node1',), config={'configurable': {'thread_id': '2', 'thread_ts': '1ef4b1d4-6311-60ae-8005-c81b709f4fb2'}}, metadata={'source': 'update', 'step': 5, 'writes': {'Node2': {'count': -3, 'lnode': 'node_1', 'scratch': 'hello'}}}, created_at='2024-07-26T07:04:17.553005+00:00', parent_config={'configurable': {'thread_id': '2', 'thread_ts': '1ef4b1d3-deb4-68a8-8004-39827de2318f'}})
#
# StateSnapshot(values={'lnode': 'node_2', 'scratch': 'hi', 'count': 4}, next=(), config={'configurable': {'thread_id': '2', 'thread_ts': '1ef4b1d3-deb4-68a8-8004-39827de2318f'}}, metadata={'source': 'loop', 'step': 4, 'writes': {'Node2': {'count': 1, 'lnode': 'node_2'}}}, created_at='2024-07-26T07:04:03.673911+00:00', parent_config={'configurable': {'thread_id': '2', 'thread_ts': '1ef4b1d3-deb1-6489-8003-3f8a828662e8'}})
#
# StateSnapshot(values={'lnode': 'node_1', 'scratch': 'hi', 'count': 3}, next=('Node2',), config={'configurable': {'thread_id': '2', 'thread_ts': '1ef4b1d3-deb1-6489-8003-3f8a828662e8'}}, metadata={'source': 'loop', 'step': 3, 'writes': {'Node1': {'count': 1, 'lnode': 'node_1'}}}, created_at='2024-07-26T07:04:03.672576+00:00', parent_config={'configurable': {'thread_id': '2', 'thread_ts': '1ef4b1d3-deae-6ff6-8002-8faf28afed99'}})

# %% [markdown]
# ### Try again with `as_node`
# When writing using `update_state()`, you want to define to the graph logic which node should be assumed as the writer. What this does is allow th graph logic to find the node on the graph. After writing the values, the `next()` value is computed by travesing the graph using the new state. In this case, the state we have was written by `Node1`. The graph can then compute the next state as being `Node2`. Note that in some graphs, this may involve going through conditional edges!  Let's try this out.

# %%
graph.update_state(thread2,save_state.values, as_node="Node1")
# Out:
# {'configurable': {'thread_id': '2',
#   'thread_ts': '1ef4b1d4-9dcd-6b70-8006-112390ba595a'}}

# %%
for i, state in enumerate(graph.get_state_history(thread2)):
    if i >= 3:  #print latest 3
        break
    print(state, '\n')
# Out:
# StateSnapshot(values={'lnode': 'node_1', 'scratch': 'hello', 'count': -2}, next=('Node2',), config={'configurable': {'thread_id': '2', 'thread_ts': '1ef4b1d4-9dcd-6b70-8006-112390ba595a'}}, metadata={'source': 'update', 'step': 6, 'writes': {'Node1': {'count': -3, 'lnode': 'node_1', 'scratch': 'hello'}}}, created_at='2024-07-26T07:04:23.712021+00:00', parent_config={'configurable': {'thread_id': '2', 'thread_ts': '1ef4b1d4-6311-60ae-8005-c81b709f4fb2'}})
#
# StateSnapshot(values={'lnode': 'node_1', 'scratch': 'hello', 'count': 1}, next=('Node1',), config={'configurable': {'thread_id': '2', 'thread_ts': '1ef4b1d4-6311-60ae-8005-c81b709f4fb2'}}, metadata={'source': 'update', 'step': 5, 'writes': {'Node2': {'count': -3, 'lnode': 'node_1', 'scratch': 'hello'}}}, created_at='2024-07-26T07:04:17.553005+00:00', parent_config={'configurable': {'thread_id': '2', 'thread_ts': '1ef4b1d3-deb4-68a8-8004-39827de2318f'}})
#
# StateSnapshot(values={'lnode': 'node_2', 'scratch': 'hi', 'count': 4}, next=(), config={'configurable': {'thread_id': '2', 'thread_ts': '1ef4b1d3-deb4-68a8-8004-39827de2318f'}}, metadata={'source': 'loop', 'step': 4, 'writes': {'Node2': {'count': 1, 'lnode': 'node_2'}}}, created_at='2024-07-26T07:04:03.673911+00:00', parent_config={'configurable': {'thread_id': '2', 'thread_ts': '1ef4b1d3-deb1-6489-8003-3f8a828662e8'}})

# %% [markdown]
# `invoke` will run from the current state if not given a particular `thread_ts`. This is now the entry that was just added.

# %%
graph.invoke(None,thread2)
# Out:
# node2, count:-2
# node1, count:-1
# node2, count:0
# node1, count:1
# node2, count:2
# {'lnode': 'node_2', 'scratch': 'hello', 'count': 3}

# %% [markdown]
# Print out the state history, notice the `scratch` value change on the latest entries.

# %%
for state in graph.get_state_history(thread2):
    print(state,"\n")
# Out:
# StateSnapshot(values={'lnode': 'node_2', 'scratch': 'hello', 'count': 3}, next=(), config={'configurable': {'thread_id': '2', 'thread_ts': '1ef4b1d4-cb0b-62ed-800b-05374053b622'}}, metadata={'source': 'loop', 'step': 11, 'writes': {'Node2': {'count': 1, 'lnode': 'node_2'}}}, created_at='2024-07-26T07:04:28.455794+00:00', parent_config={'configurable': {'thread_id': '2', 'thread_ts': '1ef4b1d4-cb08-604b-800a-be8d73a0ce0a'}})
#
# StateSnapshot(values={'lnode': 'node_1', 'scratch': 'hello', 'count': 2}, next=('Node2',), config={'configurable': {'thread_id': '2', 'thread_ts': '1ef4b1d4-cb08-604b-800a-be8d73a0ce0a'}}, metadata={'source': 'loop', 'step': 10, 'writes': {'Node1': {'count': 1, 'lnode': 'node_1'}}}, created_at='2024-07-26T07:04:28.454498+00:00', parent_config={'configurable': {'thread_id': '2', 'thread_ts': '1ef4b1d4-cb05-6fa1-8009-f994d0ab5682'}})
#
# StateSnapshot(values={'lnode': 'node_2', 'scratch': 'hello', 'count': 1}, next=('Node1',), config={'configurable': {'thread_id': '2', 'thread_ts': '1ef4b1d4-cb05-6fa1-8009-f994d0ab5682'}}, metadata={'source': 'loop', 'step': 9, 'writes': {'Node2': {'count': 1, 'lnode': 'node_2'}}}, created_at='2024-07-26T07:04:28.453662+00:00', parent_config={'configurable': {'thread_id': '2', 'thread_ts': '1ef4b1d4-cb02-6d65-8008-367eb86219ce'}})
#
# StateSnapshot(values={'lnode': 'node_1', 'scratch': 'hello', 'count': 0}, next=('Node2',), config={'configurable': {'thread_id': '2', 'thread_ts': '1ef4b1d4-cb02-6d65-8008-367eb86219ce'}}, metadata={'source': 'loop', 'step': 8, 'writes': {'Node1': {'count': 1, 'lnode': 'node_1'}}}, created_at='2024-07-26T07:04:28.452374+00:00', parent_config={'configurable': {'thread_id': '2', 'thread_ts': '1ef4b1d4-cb00-671d-8007-6bdfca2b30d5'}})
#
# StateSnapshot(values={'lnode': 'node_2', 'scratch': 'hello', 'count': -1}, next=('Node1',), config={'configurable': {'thread_id': '2', 'thread_ts': '1ef4b1d4-cb00-671d-8007-6bdfca2b30d5'}}, metadata={'source': 'loop', 'step': 7, 'writes': {'Node2': {'count': 1, 'lnode': 'node_2'}}}, created_at='2024-07-26T07:04:28.451393+00:00', parent_config={'configurable': {'thread_id': '2', 'thread_ts': '1ef4b1d4-9dcd-6b70-8006-112390ba595a'}})
#
# StateSnapshot(values={'lnode': 'node_1', 'scratch': 'hello', 'count': -2}, next=('Node2',), config={'configurable': {'thread_id': '2', 'thread_ts': '1ef4b1d4-9dcd-6b70-8006-112390ba595a'}}, metadata={'source': 'update', 'step': 6, 'writes': {'Node1': {'count': -3, 'lnode': 'node_1', 'scratch': 'hello'}}}, created_at='2024-07-26T07:04:23.712021+00:00', parent_config={'configurable': {'thread_id': '2', 'thread_ts': '1ef4b1d4-6311-60ae-8005-c81b709f4fb2'}})
#
# StateSnapshot(values={'lnode': 'node_1', 'scratch': 'hello', 'count': 1}, next=('Node1',), config={'configurable': {'thread_id': '2', 'thread_ts': '1ef4b1d4-6311-60ae-8005-c81b709f4fb2'}}, metadata={'source': 'update', 'step': 5, 'writes': {'Node2': {'count': -3, 'lnode': 'node_1', 'scratch': 'hello'}}}, created_at='2024-07-26T07:04:17.553005+00:00', parent_config={'configurable': {'thread_id': '2', 'thread_ts': '1ef4b1d3-deb4-68a8-8004-39827de2318f'}})
#
# StateSnapshot(values={'lnode': 'node_2', 'scratch': 'hi', 'count': 4}, next=(), config={'configurable': {'thread_id': '2', 'thread_ts': '1ef4b1d3-deb4-68a8-8004-39827de2318f'}}, metadata={'source': 'loop', 'step': 4, 'writes': {'Node2': {'count': 1, 'lnode': 'node_2'}}}, created_at='2024-07-26T07:04:03.673911+00:00', parent_config={'configurable': {'thread_id': '2', 'thread_ts': '1ef4b1d3-deb1-6489-8003-3f8a828662e8'}})
#
# StateSnapshot(values={'lnode': 'node_1', 'scratch': 'hi', 'count': 3}, next=('Node2',), config={'configurable': {'thread_id': '2', 'thread_ts': '1ef4b1d3-deb1-6489-8003-3f8a828662e8'}}, metadata={'source': 'loop', 'step': 3, 'writes': {'Node1': {'count': 1, 'lnode': 'node_1'}}}, created_at='2024-07-26T07:04:03.672576+00:00', parent_config={'configurable': {'thread_id': '2', 'thread_ts': '1ef4b1d3-deae-6ff6-8002-8faf28afed99'}})
#
# StateSnapshot(values={'lnode': 'node_2', 'scratch': 'hi', 'count': 2}, next=('Node1',), config={'configurable': {'thread_id': '2', 'thread_ts': '1ef4b1d3-deae-6ff6-8002-8faf28afed99'}}, metadata={'source': 'loop', 'step': 2, 'writes': {'Node2': {'count': 1, 'lnode': 'node_2'}}}, created_at='2024-07-26T07:04:03.671637+00:00', parent_config={'configurable': {'thread_id': '2', 'thread_ts': '1ef4b1d3-deaa-6e24-8001-097ff1665a4e'}})
#
# StateSnapshot(values={'lnode': 'node_1', 'scratch': 'hi', 'count': 1}, next=('Node2',), config={'configurable': {'thread_id': '2', 'thread_ts': '1ef4b1d3-deaa-6e24-8001-097ff1665a4e'}}, metadata={'source': 'loop', 'step': 1, 'writes': {'Node1': {'count': 1, 'lnode': 'node_1'}}}, created_at='2024-07-26T07:04:03.669954+00:00', parent_config={'configurable': {'thread_id': '2', 'thread_ts': '1ef4b1d3-dea7-6889-8000-8b4a919cd608'}})
#
# StateSnapshot(values={'scratch': 'hi', 'count': 0}, next=('Node1',), config={'configurable': {'thread_id': '2', 'thread_ts': '1ef4b1d3-dea7-6889-8000-8b4a919cd608'}}, metadata={'source': 'loop', 'step': 0, 'writes': None}, created_at='2024-07-26T07:04:03.668575+00:00', parent_config={'configurable': {'thread_id': '2', 'thread_ts': '1ef4b1d3-dea4-6c90-bfff-127bcaf34070'}})
#
# StateSnapshot(values={'count': 0}, next=('__start__',), config={'configurable': {'thread_id': '2', 'thread_ts': '1ef4b1d3-dea4-6c90-bfff-127bcaf34070'}}, metadata={'source': 'input', 'step': -1, 'writes': {'count': 0, 'scratch': 'hi'}}, created_at='2024-07-26T07:04:03.667448+00:00', parent_config=None)

# %% [markdown]
# Continue to experiment!
